# %% [markdown]
# ## Twitter Streaming App
# This is the code to run a Stream Listener to capture Twitter feeds based on a specific keyword list (could be hashtags)<br>
# <b>Each tweet is analysed for sentiment and emotion in realtime <br>
#    and the tweet+analysis+goe-coordinates are saved on a Cloudant database for further processing/display etc</b>

# %%
import pip
pip.__version__
# !python3 -m pip install --user tweepy
# !python3 -m pip install --user cloudant
# !pip install --upgrade watson-developer-cloud

# %% [markdown]
# The following cell contains code to connect to Twitter
# requires Twitter API keys
#
#
# def <b>connect_to_twitter():</b><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;import tweepy<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;consumerKey = 'xxxxxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;consumerSecret = 'xxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accessToken = 'xxxxxxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accessTokenSecret = 'xxxxxxxxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;auth = tweepy.OAuthHandler(consumerKey, consumerSecret)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;auth.set_access_token(accessToken, accessTokenSecret)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;return tweepy.API(auth_handler=auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)  <br>

# %%
# The code was removed by Watson Studio for sharing.

# %%
#from twitterconnect import connect_to_twitter
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %% [markdown]
# The following cell contains the credentials to access Watson NLU API
#
# #Watson NLU credentials<br>
# credentials_NLU = {<br>
#   'url':'https://gateway.watsonplatform.net/natural-language-understanding/api',<br>
#   'username':'xxxxxxxxxxxxxxxxxxxx',<br>
#   'password':'xxxxxxxxxxxxxxxxxxxxxxxx'<br>
# }<br>

# %%
# The code was removed by Watson Studio for sharing.

# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, SentimentOptions, EmotionOptions

NLU_service = NaturalLanguageUnderstandingV1(
    version='2018-03-16',
    ## url is optional, and defaults to the URL below. Use the correct URL for your region.
    # url='https://gateway.watsonplatform.net/natural-language-understanding/api',
    username=credentials_NLU['username'],
    password=credentials_NLU['password'])

# %%
# The code was removed by Watson Studio for sharing.

# %%
#connect via Spark driver

spark = SparkSession\
    .builder\
    .appName("Cloudant Storage for Tweets")\
    .config("cloudant.host",credentials_cloudant['custom_url'].split('@')[1])\
    .config("cloudant.username", credentials_cloudant['username'])\
    .config("cloudant.password",credentials_cloudant['password'])\
    .config("jsonstore.rdd.partitions", 1)\
    .getOrCreate()

#df = spark.read.load("shake_classification", "org.apache.bahir.cloudant")

# %%
#Cloudant database management

def create_database(db_name):
    database = client.create_database(db_name, throw_on_exists=False)
    if database.exists():
        print("{} database successfully created".format(db_name))
        return database
    else:
        return None
    
def delete_database(db_name):
    try :
        client.delete_database(db_name)
    except CloudantException:
        print("There was a problem deleting {}.\n".format(db_name))
    else:
        print("{} successfully deleted.\n".format(db_name))

# %%
#Tweets Streaming Classes
import datetime


def set_db_name(hashtag_list, country_list, place_bbox):
    db_name = '_'.join(hashtag_list).replace(' ', '',).replace(',', '&',).lower()
    db_name = db_name+'_'+'_'.join(country_list).replace(' ', '',).lower() if country_list !=[]  else db_name
    bbox_str = ''.join(str(place_bbox)).replace(', ','_').replace('[','').replace(']','')
    db_name = db_name+'_'+bbox_str if bbox_str !='' else db_name
    return db_name+"_tweets"


def create_stream_record(hashtag_list, country_list, place_bbox):
    db_name = set_db_name(hashtag_list, country_list, place_bbox)
    date_time = datetime.datetime.now()
    json_doc = {
        "stream_name": db_name,
        "dateCreated": date_time.isoformat().split('T')[0],
        "timeCreated": date_time.isoformat().split('T')[1],
        "hashtag_list" : hashtag_list,
        "country_list" : country_list,
        "place_bbox" : place_bbox}
    return db_name, json_doc


def get_center_coordinates(b_box):
    coords = b_box.coordinates
    return {"type": 'Point', 
            "coordinates": [sum([coords[0][x][0] for x in range(4)])/4, 
                            sum([coords[0][x][1] for x in range(4)])/4]}


def create_JSON_record(status):
    coords=None
    country=""
    if (status.coordinates != None):
        coords = status.coordinates['coordinates']
    if (status.place != None):
        coords = get_center_coordinates(status.place.bounding_box.coordinates)
        country = status.place.country_code
    try:
        response = NLU_service.analyze(text=status.text, 
            features=Features(sentiment=SentimentOptions(), emotion=EmotionOptions())).get_result()
        tweet_emotion = response['emotion']['document']['emotion']
        tweet_sentiment = response['sentiment']['document']
    except:
        tweet_emotion = {}
        tweet_sentiment = {}        
    json_doc = {
        "dateCreated": status.created_at.isoformat().split('T')[0],
        "timeCreated": status.created_at.isoformat().split('T')[1],
        "country": country,
        "coords": coords,
        "sentiment": tweet_sentiment,
        "emotion": tweet_emotion,
        "text": status.text}
    return json_doc


def is_in_localisation(status, country_list, place_bbox):
    if (country_list) !=[] and (status.place != None):
        country = status.place.country_code
        return country in country_list
    elif place_bbox !=[]:
        coords = get_center_coordinates(status.place.bounding_box)
        # TODO test for bounding box 
        return True
    else:
        return True
    


def create_GeoJSON_record(status):
    coords=None
    country=""
    if (status.coordinates != None):
        coords = status.coordinates
    if (status.place != None):
        coords = get_center_coordinates(status.place.bounding_box)
        country = status.place.country_code
    try:
        response = NLU_service.analyze(text=status.text, 
            features=Features(sentiment=SentimentOptions(), emotion=EmotionOptions())).get_result()
        tweet_emotion = response['emotion']['document']['emotion']
        tweet_sentiment = response['sentiment']['document']
    except:
        tweet_emotion = {}
        tweet_sentiment = {}        
    json_doc = {
        "type": 'Feature',
        "geometry": coords,
        "dateCreated": status.created_at.isoformat().split('T')[0],
        "timeCreated": status.created_at.isoformat().split('T')[1],
        "country": country,
        "sentiment": tweet_sentiment,
        "emotion": tweet_emotion,
        "text": status.text}
    return json_doc


class Listener(StreamListener):
    def __init__(self, tweets_database, country_list, place_bbox, verbose=False):
        super(Listener, self).__init__()
        self.tweets_database = tweets_database
        self.country_list = country_list
        self.place_bbox = place_bbox
        self.verbose = verbose
        self.counter=0
        
    def on_status(self, status):
        if (status.place != None) or (status.coordinates != None):
            if is_in_localisation(status, self.country_list, self.place_bbox):
                self.counter +=1
                json_doc = create_GeoJSON_record(status)
                new_record = self.tweets_database.create_document(json_doc)
                tweet_details = "#{:d} date/time: {}/{} country: {} coords: {}". format(self.counter,
                    json_doc["dateCreated"],json_doc["timeCreated"], 
                    json_doc["country"], json_doc["geometry"]["coordinates"])
                tweet_NLU = "sentiment: {} emotion: {}". format(json_doc["sentiment"], json_doc["emotion"])
                tweet_text = "text: {}".format(json_doc["text"])
                if self.verbose:
                    print(tweet_details+"\n"+tweet_NLU+"\n"+tweet_text)
        return True

    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False
    
        
        
class TwitterStreamer():  #Class for streaming and processing live tweets.
    def __init__(self, stream_db, hashtag_list, country_list, place_bbox, verbose=False):
        self.db_name, new_record = create_stream_record(hashtag_list, country_list, place_bbox)
        stream_db.create_document(new_record)
        self.hashtag_list = hashtag_list
        self.country_list = country_list
        self.place_bbox = place_bbox
        self.verbose = verbose
        self.tweets_database = create_database(self.db_name)        
        pass

    def stream_tweets(self):
        #This handles Twitter authetification and the connection to Twitter Streaming API
        listener = Listener(self.tweets_database, self.country_list, self.place_bbox,self.verbose)
        stream = Stream(twapi.auth, listener)
        #This line filter Twitter Streams to capture data by the keywords: 
        stream.filter(track=self.hashtag_list)

# %%
#Main streaming procedure       
    
twapi=connect_to_twitter()       
streams_database = create_database("twitter_streams_db")

country_list = []
hashtag_list = ['brexit']
place_bbox = []
        
if __name__ == '__main__':
    ts = TwitterStreamer(streams_database, hashtag_list, country_list, place_bbox, True)
    try:
        ts.stream_tweets()
    except KeyboardInterrupt:
        print("exited early")
    #client.disconnect()
# Out:
# twitter_streams_db database successfully created
# brexit_tweets database successfully created
# #1 date/time: 2018-10-19/14:56:52 country: GB coords: [-1.7874955, 52.447226]
# sentiment: {'score': -0.699925, 'label': 'negative'} emotion: {'sadness': 0.195009, 'joy': 0.112054, 'anger': 0.408608, 'disgust': 0.219387, 'fear': 0.315313}
# text: Ok...bye and don’t let the door hit you on the way out..
# #2 date/time: 2018-10-19/14:57:12 country: IE coords: [-9.110049499999999, 52.858974]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.165327, 'joy': 0.49331, 'anger': 0.091925, 'disgust': 0.048812, 'fear': 0.245837}
# text: Wake up, France &amp; British admirers of Macron! #Macron is France's version of #TonyBlair; therefore, my French frien… https://t.co/scMId9J3Hp
# #3 date/time: 2018-10-19/14:57:28 country: GB coords: [-1.5710735, 54.984875]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.083082, 'joy': 0.460064, 'anger': 0.092251, 'disgust': 0.094356, 'fear': 0.070514}
# text: Colludes in alt right project Brexit and calls himself a “socialist”
# #4 date/time: 2018-10-19/14:57:47 country: GB coords: [-0.33394250000000003, 53.765817]
# sentiment: {'score': 0.676112, 'label': 'positive'} emotion: {'sadness': 0.194792, 'joy': 0.476324, 'anger': 0.109358, 'disgust': 0.170341, 'fear': 0.093884}
# text: Well said that man!
# #5 date/time: 2018-10-19/14:58:36 country: GB coords: [-5.0740479999999994, 50.151925000000006]
# sentiment: {'score': -0.816545, 'label': 'negative'} emotion: {'sadness': 0.354691, 'joy': 0.254872, 'anger': 0.053044, 'disgust': 0.099181, 'fear': 0.117149}
# text: @DianeJamesMEP Brexit voters are nostalgic for democracy @MichelBarnier something the EU knows nothing about. We Br… https://t.co/L3CqesJ94Y
# #6 date/time: 2018-10-19/14:59:25 country: GB coords: [-0.33394250000000003, 53.765817]
# sentiment: {'score': -0.754816, 'label': 'negative'} emotion: {'sadness': 0.481686, 'joy': 0.159082, 'anger': 0.161293, 'disgust': 0.085544, 'fear': 0.33553}
# text: Lazy sod wouldn’t be arsed even if he had more than mince between his ears.
# #7 date/time: 2018-10-19/15:00:57 country: GB coords: [-1.508545, 53.6791975]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.276694, 'joy': 0.198395, 'anger': 0.291325, 'disgust': 0.288502, 'fear': 0.177141}
# text: @MattWingett @antonchanning @GregClinker @scarlettpeach @VeeCee30 Being anti Brexit is totally different from argui… https://t.co/V8HGCZ32ph
# #8 date/time: 2018-10-19/15:01:04 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {} emotion: {}
# text: Haha! https://t.co/Ro6ybWOFEf
# #9 date/time: 2018-10-19/15:01:24 country: ES coords: [-4.552328, 36.597080500000004]
# sentiment: {'score': -0.616353, 'label': 'negative'} emotion: {'sadness': 0.191607, 'joy': 0.090869, 'anger': 0.32807, 'disgust': 0.216208, 'fear': 0.215354}
# text: @Conservatives Screwing up BREXIT
# #10 date/time: 2018-10-19/15:02:15 country: GB coords: [-0.21610800000000002, 51.498387]
# sentiment: {'score': -0.506578, 'label': 'negative'} emotion: {'sadness': 0.474985, 'joy': 0.085513, 'anger': 0.188066, 'disgust': 0.462422, 'fear': 0.085496}
# text: Khan seems to have forgotten that more people in London voted for Brexit than voted for him.
# #11 date/time: 2018-10-19/15:02:37 country: GB coords: [-0.2527539999999999, 51.3854455]
# sentiment: {'score': -0.824963, 'label': 'negative'} emotion: {'sadness': 0.372219, 'joy': 0.053872, 'anger': 0.429334, 'disgust': 0.308427, 'fear': 0.018702}
# text: Not impressed with delays on #M20 thanks to lorry lande being built. #Brexit #pathetic
# #12 date/time: 2018-10-19/15:02:43 country: GB coords: [-1.4901434999999998, 54.79103500000001]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.042115, 'joy': 0.083708, 'anger': 0.10375, 'disgust': 0.052652, 'fear': 0.025059}
# text: @guardian Yes, but in 2016, people didn't know what they were voting for! Now that Theresa May has consulted her pa… https://t.co/DW9Du2Kcck
# #13 date/time: 2018-10-19/15:02:56 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {'score': -0.682805, 'label': 'negative'} emotion: {'sadness': 0.351108, 'joy': 0.200484, 'anger': 0.114318, 'disgust': 0.135275, 'fear': 0.189809}
# text: Bye bye work and Brexit for 3 weeks, 🇬🇧🇪🇺🇺🇸
# #14 date/time: 2018-10-19/15:02:59 country: GB coords: [-1.7396195000000003, 55.13141850000001]
# sentiment: {'score': -0.547404, 'label': 'negative'} emotion: {'sadness': 0.219415, 'joy': 0.075017, 'anger': 0.222991, 'disgust': 0.201936, 'fear': 0.309282}
# text: Theresa May isolated as party turns on 'chaotic' Brexit plan and EU leaders give her the cold shoulder… https://t.co/TehqhqO4M3
# #15 date/time: 2018-10-19/15:03:28 country: IE coords: [-6.174398500000001, 53.257283]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.410715, 'joy': 0.077877, 'anger': 0.066157, 'disgust': 0.101531, 'fear': 0.051428}
# text: @DanielJHannan 7th now since the #Brexit Referendum
# #16 date/time: 2018-10-19/15:03:51 country: GB coords: [-1.5301095, 52.5428055]
# sentiment: {'score': -0.446986, 'label': 'negative'} emotion: {'sadness': 0.178744, 'joy': 0.277558, 'anger': 0.021017, 'disgust': 0.097495, 'fear': 0.105677}
# text: Let me know when it gets to 17.5m 👍🙄
# #17 date/time: 2018-10-19/15:04:03 country: DE coords: [13.4246065, 52.506701]
# sentiment: {'score': -0.737863, 'label': 'negative'} emotion: {'sadness': 0.236995, 'joy': 0.032755, 'anger': 0.156737, 'disgust': 0.018282, 'fear': 0.721258}
# text: @dave_odo @MeachamDave @Bandage22 @darrengrimes_ Nope. German car makers wake up worrying about AI, driverless vehi… https://t.co/ShLCe2l9Ir
# #18 date/time: 2018-10-19/15:04:20 country: GB coords: [-3.0044560000000002, 53.4698505]
# sentiment: {} emotion: {}
# text: Excellent. 👏👏👏👏
# #19 date/time: 2018-10-19/15:04:33 country: GB coords: [0.07886299999999999, 51.584990000000005]
# sentiment: {'score': -0.677009, 'label': 'negative'} emotion: {'sadness': 0.563202, 'joy': 0.019351, 'anger': 0.384322, 'disgust': 0.217552, 'fear': 0.06397}
# text: @Jacob_Rees_Mogg I know, Mr Mogg, this will delay you and the gutless fools you support, making a run for her job,… https://t.co/NrAcCro6gf
# #20 date/time: 2018-10-19/15:04:34 country: GB coords: [-1.2334335, 51.75428599999999]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.407917, 'joy': 0.151966, 'anger': 0.190336, 'disgust': 0.162163, 'fear': 0.086128}
# text: @Jacob_Rees_Mogg Any idea how much Brexit is and will cost the UK and people who run businesses? You seem to always… https://t.co/meX30hlRYx
# #21 date/time: 2018-10-19/15:05:12 country: GB coords: [-2.2038685, 52.526056499999996]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.182828, 'joy': 0.268782, 'anger': 0.132129, 'disgust': 0.123901, 'fear': 0.094905}
# text: @efc_am @ElectionMapsUK @Survation If the polls that claim everyone has changed their mind on brexit were true the… https://t.co/buKoQ9yg6X
# #22 date/time: 2018-10-19/15:06:53 country: IE coords: [-9.0333065, 51.903863]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text: #brexit https://t.co/6wiyvxZsw7
# #23 date/time: 2018-10-19/15:07:10 country: GB coords: [-2.250699, 52.381068]
# sentiment: {'score': 0.587158, 'label': 'positive'} emotion: {'sadness': 0.137462, 'joy': 0.745193, 'anger': 0.006248, 'disgust': 0.012701, 'fear': 0.106688}
# text: Great, Freedom Abroad and Compassion at Home 👍
# #24 date/time: 2018-10-19/15:07:22 country: GB coords: [-2.915427, 53.4198785]
# sentiment: {'score': -0.811484, 'label': 'negative'} emotion: {'sadness': 0.415737, 'joy': 0.071728, 'anger': 0.140222, 'disgust': 0.073196, 'fear': 0.208196}
# text: @tom_watson @DanielJHannan Saved.. the EU trough has been rebuilt again but in California. Trouble is so many busin… https://t.co/ZcbuJhG0ZR
# #25 date/time: 2018-10-19/15:07:46 country: GB coords: [-4.4251495, 55.910872999999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.188413, 'joy': 0.070997, 'anger': 0.049997, 'disgust': 0.070348, 'fear': 0.065592}
# text: @SiannamacDonald @theSNP It will not be until "the terms of Brexit are known". That position is unlikely to change.… https://t.co/kClIFrptA0
# #26 date/time: 2018-10-19/15:08:26 country: BE coords: [4.4428455, 50.9023955]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text: #brexit https://t.co/F81qRBEzS4
# #27 date/time: 2018-10-19/15:08:41 country: GB coords: [-2.1556405, 53.4146085]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.215008, 'joy': 0.143958, 'anger': 0.117269, 'disgust': 0.373485, 'fear': 0.122782}
# text: Theresa May MP: Give People a Final Say on Brexit Deal - Sign the Petition! https://t.co/9c1NkY66bS via @UKChange
# #28 date/time: 2018-10-19/15:09:25 country: IE coords: [-6.2476215, 53.354902499999994]
# sentiment: {'score': 0.304345, 'label': 'positive'} emotion: {'sadness': 0.055011, 'joy': 0.718814, 'anger': 0.054146, 'disgust': 0.027276, 'fear': 0.052558}
# text: Jolly good. Come on, you Brits!!
# #29 date/time: 2018-10-19/15:10:08 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {'score': -0.520064, 'label': 'negative'} emotion: {'sadness': 0.293378, 'joy': 0.028458, 'anger': 0.165023, 'disgust': 0.080929, 'fear': 0.704527}
# text: Dangerous talk gerry
# #30 date/time: 2018-10-19/15:10:22 country: GB coords: [-0.21610800000000002, 51.498387]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.118792, 'joy': 0.321243, 'anger': 0.174508, 'disgust': 0.469904, 'fear': 0.032895}
# text: @JamesManuell Yes. But more people voted for Brexit than voted for Sadiq Khan.
#
# There were around 200,000 more vote… https://t.co/byXE1vKo2q
# #31 date/time: 2018-10-19/15:11:26 country: GB coords: [-1.974027, 52.67216500000001]
# sentiment: {'score': -0.353306, 'label': 'negative'} emotion: {'sadness': 0.262436, 'joy': 0.413856, 'anger': 0.11211, 'disgust': 0.273418, 'fear': 0.073827}
# text: @georgiebingham Yeah women have got the vote , brexit still ain’t happened , villa finally got rid of Bruce apart f… https://t.co/6aV4ZO64rb
# #32 date/time: 2018-10-19/15:12:13 country: BE coords: [4.3086935, 50.909325]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.276788, 'joy': 0.256128, 'anger': 0.079281, 'disgust': 0.099499, 'fear': 0.41135}
# text: https://t.co/BpHNe0JrxY May The, Force be with your nombril... Sissi Là, Reine de l'univers témoigne avec Le, Seign… https://t.co/fxSGDUNnsc
# #33 date/time: 2018-10-19/15:12:15 country: GB coords: [-4.069734, 52.4105665]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.118116, 'joy': 0.054759, 'anger': 0.089791, 'disgust': 0.147097, 'fear': 0.21091}
# text: @DavidGArnold Are you rehearsing for the post-Brexit period?
# #34 date/time: 2018-10-19/15:12:55 country: GB coords: [-0.08816099999999999, 51.489262999999994]
# sentiment: {'score': -0.842745, 'label': 'negative'} emotion: {'sadness': 0.695167, 'joy': 0.013795, 'anger': 0.228159, 'disgust': 0.124824, 'fear': 0.18131}
# text: The last thing we need is a political stitch-up that leaves us all worse off. Let’s take to the streets and make th… https://t.co/XgTNNcrsuc
# #35 date/time: 2018-10-19/15:13:40 country: GB coords: [-0.278464, 51.390063]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.22226, 'joy': 0.305066, 'anger': 0.131373, 'disgust': 0.267094, 'fear': 0.167249}
# text: 🌹Just a pleasant thought Clare, but perhaps defrosting the PM with a hammer might have put the tool to better use?🤔… https://t.co/2Qx2k3ZvBL
# #36 date/time: 2018-10-19/15:14:36 country: GB coords: [-0.47672, 51.6406205]
# sentiment: {'score': -0.624066, 'label': 'negative'} emotion: {'sadness': 0.361398, 'joy': 0.143826, 'anger': 0.293395, 'disgust': 0.169761, 'fear': 0.158927}
# text: @RaymondSnoddy #PeoplesMarch
# Part 4
# If Brexit is a mistake it must be seen by the people as one
# Only then will hist… https://t.co/kEQ2ZWJDY2
# #37 date/time: 2018-10-19/15:15:23 country: GB coords: [-0.47672, 51.6406205]
# sentiment: {'score': -0.295121, 'label': 'negative'} emotion: {'sadness': 0.226204, 'joy': 0.345147, 'anger': 0.093594, 'disgust': 0.174782, 'fear': 0.148528}
# text: @EchoingQuack @ThomasEvansSDP @kenty227 @bbcquestiontime On the plus side, I dont think ive caught the Brexit super… https://t.co/mgJrMJsw3S
# #38 date/time: 2018-10-19/15:15:27 country: US coords: [-122.2286855, 37.791994]
# sentiment: {'score': -0.674461, 'label': 'negative'} emotion: {'sadness': 0.681911, 'joy': 0.004054, 'anger': 0.158172, 'disgust': 0.169775, 'fear': 0.195504}
# text: .@duponline lost any claim to ‘common sense’ with their train wreck Brexit. As usual, @little_pengelly’s comments a… https://t.co/cbrimFy2SQ
# #39 date/time: 2018-10-19/15:15:35 country: GB coords: [-2.2118700000000002, 52.194918]
# sentiment: {'score': -0.309182, 'label': 'negative'} emotion: {'sadness': 0.070163, 'joy': 0.076507, 'anger': 0.068787, 'disgust': 0.837166, 'fear': 0.031515}
# text: Check out this Tory fruitcake
# #40 date/time: 2018-10-19/15:16:29 country: FR coords: [0.2673945, 44.666531500000005]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.186573, 'joy': 0.149491, 'anger': 0.11499, 'disgust': 0.239355, 'fear': 0.132486}
# text: If evidence were needed that Rees Mogg was a nut job here it is. He wants high powered rifles to be able to be lega… https://t.co/frt6DUXvN1
# #41 date/time: 2018-10-19/15:18:03 country: DE coords: [13.4246065, 52.506701]
# sentiment: {'score': 0.544252, 'label': 'positive'} emotion: {'sadness': 0.347471, 'joy': 0.171899, 'anger': 0.08331, 'disgust': 0.223765, 'fear': 0.14914}
# text: I genuinely thought this was a @thedailymash headline when I first read it:
#
# "Jeremy Hunt: EU more constructive sin… https://t.co/4Y9UeUmMjc
# #42 date/time: 2018-10-19/15:18:14 country: GB coords: [-0.19371950000000002, 51.4516565]
# sentiment: {'score': 0.773218, 'label': 'positive'} emotion: {'sadness': 0.075196, 'joy': 0.681486, 'anger': 0.017789, 'disgust': 0.019533, 'fear': 0.004343}
# text: Hello @MarshadeCordova
# #battersea would appreciate a similar statement on your willingness to represent us.
# Love,… https://t.co/gz6dKTHsHp
# #43 date/time: 2018-10-19/15:18:23 country: GB coords: [0.206629, 51.4402245]
# sentiment: {'score': -0.689744, 'label': 'negative'} emotion: {'sadness': 0.234423, 'joy': 0.429471, 'anger': 0.073667, 'disgust': 0.111315, 'fear': 0.149604}
# text: Nobody is keeping you here bye 👋 bye 👋
# #44 date/time: 2018-10-19/15:18:32 country: FR coords: [0.2673945, 44.666531500000005]
# sentiment: {'score': -0.389718, 'label': 'negative'} emotion: {'sadness': 0.441507, 'joy': 0.095466, 'anger': 0.097586, 'disgust': 0.131076, 'fear': 0.165584}
# text: Lib Dems to begin process of selecting MEP candidates for European elections - despite #Brexit https://t.co/S0yqIsGsVV
# #45 date/time: 2018-10-19/15:18:45 country: GB coords: [-0.2527539999999999, 51.3854455]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.184564, 'joy': 0.127302, 'anger': 0.203817, 'disgust': 0.352929, 'fear': 0.196112}
# text: Presenter on @BBCRADIOKENT "We're discussing the fact that there are 50% more working mums than in the 1970s. Are w… https://t.co/sk7nRNw5O4
# #46 date/time: 2018-10-19/15:19:26 country: GB coords: [-4.200441, 57.739454]
# sentiment: {'score': -0.695603, 'label': 'negative'} emotion: {'sadness': 0.209993, 'joy': 0.075638, 'anger': 0.548701, 'disgust': 0.385508, 'fear': 0.031108}
# text: Despair as general election and/or People's vote still not happening and murderous, rich, dick suckers remain in ch… https://t.co/5NjIPOVHVH
# #47 date/time: 2018-10-19/15:20:04 country: GB coords: [-4.0662275, 55.778186]
# sentiment: {'score': -0.539222, 'label': 'negative'} emotion: {'sadness': 0.586565, 'joy': 0.046738, 'anger': 0.109985, 'disgust': 0.408028, 'fear': 0.081746}
# text: @SiannamacDonald @theSNP Tories days are numbered brexit negotiations doubt EU will tolerate anymore from them come… https://t.co/AmWpjsSssK
# #48 date/time: 2018-10-19/15:20:29 country: HK coords: [114.139883, 22.276870000000002]
# sentiment: {} emotion: {}
# text: LOL!
# #49 date/time: 2018-10-19/15:20:48 country: AE coords: [55.5511725, 24.9934625]
# sentiment: {'score': -0.39951, 'label': 'negative'} emotion: {'sadness': 0.390495, 'joy': 0.146378, 'anger': 0.12124, 'disgust': 0.235083, 'fear': 0.23194}
# text: Perhaps the situation has changed since he was involved....just a thought...
# #50 date/time: 2018-10-19/15:21:06 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {'score': -0.687696, 'label': 'negative'} emotion: {'sadness': 0.665944, 'joy': 0.007776, 'anger': 0.162936, 'disgust': 0.366257, 'fear': 0.115198}
# text: If you think Brexit will leave us weaker and poorer, march for a people’s vote | Timothy Garton Ash https://t.co/uqLhE2De5N
# #51 date/time: 2018-10-19/15:21:25 country: GB coords: [-0.08816099999999999, 51.489262999999994]
# sentiment: {'score': 0.0183809, 'label': 'positive'} emotion: {'sadness': 0.356182, 'joy': 0.085545, 'anger': 0.176034, 'disgust': 0.194771, 'fear': 0.21831}
# text: Hi there! Are you marching with us TOMORROW to save the UK from the disaster that's Brexit? I will be marching with… https://t.co/4uHNXmdxYk
# #52 date/time: 2018-10-19/15:22:30 country: FR coords: [1.822424, 50.927927]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.315838, 'joy': 0.26141, 'anger': 0.217318, 'disgust': 0.093396, 'fear': 0.049828}
# text: Famous last words #brexit https://t.co/aXSIv1KvWH
# #53 date/time: 2018-10-19/15:22:45 country: GB coords: [-0.0706035, 51.464686]
# sentiment: {'score': -0.496065, 'label': 'negative'} emotion: {'sadness': 0.078653, 'joy': 0.623165, 'anger': 0.048379, 'disgust': 0.001384, 'fear': 0.088977}
# text: I'm looking forward to joining the masses at the #PeoplesVoteMarch tomorrow; we are demanding a #FinalSay on the… https://t.co/2FyzzMHmK1
# #54 date/time: 2018-10-19/15:22:58 country: GB coords: [-0.21610800000000002, 51.498387]
# sentiment: {'score': 0.897242, 'label': 'positive'} emotion: {'sadness': 0.094796, 'joy': 0.305452, 'anger': 0.295948, 'disgust': 0.345043, 'fear': 0.135831}
# text: BREXITERS NEED A VOTE !
#
# REMAINERS NEED A VOTE!
#
# WE ALL NEED A VOTE!
#
# A meaningful vote one  base… https://t.co/ZpDopUUPfi
# #55 date/time: 2018-10-19/15:23:12 country: GB coords: [0.317777, 51.4864855]
# sentiment: {'score': -0.676882, 'label': 'negative'} emotion: {'sadness': 0.09155, 'joy': 0.049393, 'anger': 0.890699, 'disgust': 0.117381, 'fear': 0.039141}
# text: Love that the Guardianistas have gone for sneering at the 'elite' Remainers. Fuck off. Stop. Then fuck off again. P… https://t.co/tCJ0NA4iot
# #56 date/time: 2018-10-19/15:23:40 country: GB coords: [-0.0350195, 51.5148305]
# sentiment: {'score': -0.817881, 'label': 'negative'} emotion: {'sadness': 0.110745, 'joy': 0.631162, 'anger': 0.010739, 'disgust': 0.145476, 'fear': 0.077953}
# text: #NK has been best QT panellist in ages. Summed up the #Brexit mess perfectly. 👏🏻🤔
# #57 date/time: 2018-10-19/15:23:46 country: GB coords: [-2.4349525, 53.5841845]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.253677, 'joy': 0.149797, 'anger': 0.079023, 'disgust': 0.112595, 'fear': 0.389202}
# text: @KTHopkins @rockingZboat Wonder if this could be on @bbcquestiontime next week, I know it’s a subject you don’t car… https://t.co/tR2OjXfXx2
# #58 date/time: 2018-10-19/15:24:05 country: GB coords: [-0.5701175, 51.236420499999994]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.587172, 'joy': 0.076491, 'anger': 0.32629, 'disgust': 0.054868, 'fear': 0.093796}
# text: @mirabarhillel Except his position is still that, despite being a Remainer, we should still push ahead with this s*… https://t.co/xM831IGAJ3
# #59 date/time: 2018-10-19/15:24:59 country: GB coords: [-1.2695275, 50.866556]
# sentiment: {'score': -0.657449, 'label': 'negative'} emotion: {'sadness': 0.187485, 'joy': 0.01408, 'anger': 0.66921, 'disgust': 0.175554, 'fear': 0.222813}
# text: I’m not your go-to protestor, but I can’t sit back and just resign myself and my countrymen to this brexit shit-sho… https://t.co/GkJt1IxRqe
# #60 date/time: 2018-10-19/15:25:38 country: US coords: [-83.206106, 35.9557305]
# sentiment: {'score': 0.448545, 'label': 'positive'} emotion: {'sadness': 0.226914, 'joy': 0.261538, 'anger': 0.034133, 'disgust': 0.222631, 'fear': 0.193452}
# text: Merkel 'unequivocally' supports Ireland over Brexit https://t.co/x0iuUkpqn3 via @rte
# #61 date/time: 2018-10-19/15:25:41 country: GB coords: [-2.9367240000000003, 51.217709]
# sentiment: {'score': -0.693614, 'label': 'negative'} emotion: {'sadness': 0.314849, 'joy': 0.305809, 'anger': 0.052791, 'disgust': 0.185922, 'fear': 0.165378}
# text: @UKGovScotland @ScotRenew alas your overlords in #Westminster have consistently reduced support &amp; subsidy from all… https://t.co/dbsmLdohsP
# #62 date/time: 2018-10-19/15:25:58 country: GB coords: [-0.11540600000000001, 51.4603395]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.140491, 'joy': 0.282492, 'anger': 0.129382, 'disgust': 0.026621, 'fear': 0.129924}
# text: Lead and they shall follow.
# #63 date/time: 2018-10-19/15:26:26 country: GB coords: [0.406984, 52.248934500000004]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.228485, 'joy': 0.24282, 'anger': 0.197304, 'disgust': 0.10051, 'fear': 0.055652}
# text: The prime reason to remain.
# #64 date/time: 2018-10-19/15:27:20 country: GB coords: [-1.449612, 53.3831645]
# sentiment: {'score': -0.573542, 'label': 'negative'} emotion: {'sadness': 0.442267, 'joy': 0.120412, 'anger': 0.124525, 'disgust': 0.365349, 'fear': 0.228557}
# text: Why has the media so many folk whose central philosophy appears to be ‘Never let the facts impinge on my prejudice’.
# #65 date/time: 2018-10-19/15:28:10 country:  coords: [-180, 85.05112878]
# sentiment: {'score': -0.385348, 'label': 'negative'} emotion: {'sadness': 0.068587, 'joy': 0.033376, 'anger': 0.100458, 'disgust': 0.059141, 'fear': 0.047195}
# text: BBC News Brexit: France's Macron makes English faux pas over visas: UK visitors will not need French visas if there… https://t.co/7PpAM2f5n4
# #66 date/time: 2018-10-19/15:29:09 country: GB coords: [-1.2074825, 53.9318445]
# sentiment: {'score': -0.304558, 'label': 'negative'} emotion: {'sadness': 0.145145, 'joy': 0.240084, 'anger': 0.143583, 'disgust': 0.074596, 'fear': 0.113607}
# text: Quite strange that these Remain Ultras use Trump as their meme rather than anything that has any connection at all… https://t.co/AnXutlQqFe
# #67 date/time: 2018-10-19/15:29:34 country: GB coords: [-0.08816099999999999, 51.489262999999994]
# sentiment: {'score': 0.734758, 'label': 'positive'} emotion: {'sadness': 0.0593, 'joy': 0.194323, 'anger': 0.095716, 'disgust': 0.033499, 'fear': 0.044033}
# text: @shaunksread @_R_J_B_ @JohnSpringford Like the European Medicines Agency for example. We shared the cost of testing… https://t.co/KObvm6CKWB
# #68 date/time: 2018-10-19/15:29:55 country: TT coords: [-61.211783, 10.700476]
# sentiment: {'score': -0.311455, 'label': 'negative'} emotion: {'sadness': 0.124111, 'joy': 0.10472, 'anger': 0.169333, 'disgust': 0.093792, 'fear': 0.172809}
# text: We're headed off a cliff
# #69 date/time: 2018-10-19/15:30:33 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': -0.0263997, 'label': 'negative'} emotion: {'sadness': 0.380265, 'joy': 0.290271, 'anger': 0.091961, 'disgust': 0.124383, 'fear': 0.187906}
# text: Yippee! Clegg has been hired by Facebook. He’s going to move to America for lots of lolly. No more banging on like… https://t.co/CWPi12flcw
# #70 date/time: 2018-10-19/15:30:50 country: GB coords: [-4.0662275, 55.778186]
# sentiment: {'score': 0.890541, 'label': 'positive'} emotion: {'sadness': 0.030918, 'joy': 0.51148, 'anger': 0.179102, 'disgust': 0.024543, 'fear': 0.2308}
# text: @y_alibhai Thank you Yasmin a sane voice in the brexit noise!
# #71 date/time: 2018-10-19/15:30:55 country: GB coords: [-0.102162, 51.5879015]
# sentiment: {'score': -0.818388, 'label': 'negative'} emotion: {'sadness': 0.226388, 'joy': 0.018155, 'anger': 0.035564, 'disgust': 0.046209, 'fear': 0.406431}
# text: @SpygirlUK @ChrisJones_1 @andrew_lilico Oops - here's the short version of their report. P. 5 is particularly relev… https://t.co/2evN7iOKEJ
# #72 date/time: 2018-10-19/15:31:45 country: DE coords: [9.278796999999999, 48.820535]
# sentiment: {'score': -0.783177, 'label': 'negative'} emotion: {'sadness': 0.870354, 'joy': 0.041161, 'anger': 0.007456, 'disgust': 0.115, 'fear': 0.124156}
# text: @BestForBritain Die spinnen, die Engländer
# #Brexit auf deutsch with subtitles 😂
# https://t.co/SejsN7FDnu
# #73 date/time: 2018-10-19/15:32:40 country: GB coords: [-0.672516, 53.565245]
# sentiment: {'score': -0.893778, 'label': 'negative'} emotion: {'sadness': 0.09185, 'joy': 0.005383, 'anger': 0.665716, 'disgust': 0.502483, 'fear': 0.081148}
# text: Apart from #brexit, one other thing I hate, is when someone uses a sit down toilet for a piss at a supermarket, whe… https://t.co/rfbZ42fNnV
# #74 date/time: 2018-10-19/15:32:43 country: GB coords: [1.0901355, 51.27675550000001]
# sentiment: {'score': -0.424901, 'label': 'negative'} emotion: {'sadness': 0.213961, 'joy': 0.085861, 'anger': 0.317649, 'disgust': 0.127131, 'fear': 0.239484}
# text: @willrb5 @SupportOurLefty @petuniasforever @LeaveMnsLeave         ....you sure this isn't the UK's chief Brexit negotiator ?
# #75 date/time: 2018-10-19/15:32:56 country: GB coords: [0.2515055, 51.142153]
# sentiment: {'score': 0.67137, 'label': 'positive'} emotion: {'sadness': 0.378114, 'joy': 0.234812, 'anger': 0.094693, 'disgust': 0.110515, 'fear': 0.064736}
# text: She knows everything about single market and custom union and her vote was informed .......
# #76 date/time: 2018-10-19/15:33:06 country: GB coords: [-0.09263300000000001, 51.358931]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.444459, 'joy': 0.102866, 'anger': 0.343784, 'disgust': 0.203089, 'fear': 0.053692}
# text: There’s an old lad at Gatwick airport with a ‘bollocks to Brexit’ t shirt carrying a ‘player on the playa’ tote bag… https://t.co/V5yNQ0NDCs
# #77 date/time: 2018-10-19/15:33:33 country: IE coords: [-8.3498705, 53.6975265]
# sentiment: {'score': -0.636456, 'label': 'negative'} emotion: {'sadness': 0.594463, 'joy': 0.087142, 'anger': 0.009808, 'disgust': 0.271499, 'fear': 0.218946}
# text: @kildaregaa365 @Catherine3123 Dropping off the pile of shite that’s called Brexit 😀😂😂
# #78 date/time: 2018-10-19/15:34:40 country: GB coords: [0.5115780000000001, 52.2204505]
# sentiment: {'score': 0.2825, 'label': 'positive'} emotion: {'sadness': 0.054063, 'joy': 0.809109, 'anger': 0.046017, 'disgust': 0.068645, 'fear': 0.02785}
# text: Well done, Femi, keeping your cool. Noticed something about Leavers. They have no arguments that stand up to scruti… https://t.co/9triaxIkO3
# #79 date/time: 2018-10-19/15:35:16 country: GB coords: [-3.3144405, 57.6463415]
# sentiment: {'score': -0.449869, 'label': 'negative'} emotion: {'sadness': 0.303147, 'joy': 0.099708, 'anger': 0.011402, 'disgust': 0.065923, 'fear': 0.135106}
# text: @BigSte36 @MRickelton That's certainly what happened with #indyref . Vote no to stay in EU, lead us don't leave us,… https://t.co/V9TezjLxh7
# #80 date/time: 2018-10-19/15:35:46 country: GB coords: [0.206629, 51.4402245]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.186381, 'joy': 0.011015, 'anger': 0.104997, 'disgust': 0.843425, 'fear': 0.10147}
# text: Because Camp bell is insane labour loony loopy Basket Case 😡👀👿🤮
# #81 date/time: 2018-10-19/15:35:59 country: IE coords: [-6.399521, 53.2735025]
# sentiment: {'score': -0.318204, 'label': 'negative'} emotion: {'sadness': 0.138227, 'joy': 0.292712, 'anger': 0.032851, 'disgust': 0.040073, 'fear': 0.069429}
# text: @BartLad69 @Think32_ @PoliceServiceNI @ChiefConPSNI No matter what Brexit brings we have to move forward positively… https://t.co/WJI0kd5mGJ
# #82 date/time: 2018-10-19/15:36:02 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.071039, 'joy': 0.591774, 'anger': 0.075572, 'disgust': 0.230707, 'fear': 0.084333}
# text: I’m no nationalist, but given their reservedness and integrity in the face of the Good Friday Agreement being spat… https://t.co/0C4eCRUT2T
# #83 date/time: 2018-10-19/15:36:05 country: ES coords: [2.1412275000000003, 41.392657]
# sentiment: {} emotion: {}
# text: Políticos británicos pidiendo que no haya #Brexit para evitarse tener que destrozarse la mano firmando decenas de n… https://t.co/2fuB2T8xXj
# #84 date/time: 2018-10-19/15:36:09 country: US coords: [-79.861034, 35.1704985]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.271064, 'joy': 0.494107, 'anger': 0.029604, 'disgust': 0.184245, 'fear': 0.043612}
# text: @Tony19542 @PRheydt Well, she doesn't even support her own people (BREXIT) so thats not much of a surprise. #MAGAveteran
# #85 date/time: 2018-10-19/15:36:15 country: CA coords: [-122.67191650000001, 49.2745735]
# sentiment: {'score': -0.673278, 'label': 'negative'} emotion: {'sadness': 0.181164, 'joy': 0.003206, 'anger': 0.20891, 'disgust': 0.316728, 'fear': 0.133373}
# text: #metoo extremists? Really @ABDanielleSmith ??? When was the last time you had a survivor or a staff member of a sex… https://t.co/9o7g3XWTZZ
# #86 date/time: 2018-10-19/15:37:32 country: GB coords: [-0.57184, 51.458746500000004]
# sentiment: {'score': -0.668355, 'label': 'negative'} emotion: {'sadness': 0.126275, 'joy': 0.255061, 'anger': 0.464494, 'disgust': 0.02773, 'fear': 0.224652}
# text: @faborez unfortunately Iraq was another British invention. It was also a power keg waiting to explode, check out Mi… https://t.co/J1qvVeQd0m
# #87 date/time: 2018-10-19/15:37:35 country: IE coords: [-6.579388000000001, 52.4597335]
# sentiment: {'score': 0.12351, 'label': 'positive'} emotion: {'sadness': 0.090666, 'joy': 0.536102, 'anger': 0.328474, 'disgust': 0.09055, 'fear': 0.024329}
# text: Fractured Crowd. Opens tomorrow (20 Oct)in Wexford Arts Centre at 3pm. All welcome. Image; Protest Crowd. Brexit, L… https://t.co/DzueywsrvM
# #88 date/time: 2018-10-19/15:38:00 country: GB coords: [-0.5701175, 51.236420499999994]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.118269, 'joy': 0.132121, 'anger': 0.060856, 'disgust': 0.155467, 'fear': 0.036283}
# text: @Keir_Starmer I expect to see you and as many of your fellow MPs at #PeoplesVoteMarch tomorrow.
#
# It’s about time… https://t.co/iWCwZQ9DTe
# #89 date/time: 2018-10-19/15:38:06 country: GB coords: [-1.1722659999999998, 52.969719]
# sentiment: {'score': -0.520553, 'label': 'negative'} emotion: {'sadness': 0.215431, 'joy': 0.479222, 'anger': 0.121089, 'disgust': 0.123252, 'fear': 0.147891}
# text: On the other hand just turn up for a walk about something we have already had!
# #90 date/time: 2018-10-19/15:38:12 country: GB coords: [-2.7751314999999996, 54.068005]
# sentiment: {'score': 0.928615, 'label': 'positive'} emotion: {'sadness': 0.04031, 'joy': 0.858041, 'anger': 0.015574, 'disgust': 0.006546, 'fear': 0.095072}
# text: Fantastic to be in #Cumbria today and join #Penrith and the Border @Conservatives for lunch. As always, a very live… https://t.co/b7us7MTHhh
# #91 date/time: 2018-10-19/15:39:03 country: GB coords: [-0.0601675, 51.547644500000004]
# sentiment: {'score': -0.541134, 'label': 'negative'} emotion: {'sadness': 0.166006, 'joy': 0.351964, 'anger': 0.019119, 'disgust': 0.16663, 'fear': 0.443421}
# text: Tomorrow we march for @LabPeoplesVote. Only Labour can transform UK &amp;EU @Another_Europe @nickdearden75 @Manuel_TSSA  https://t.co/5ryQuvsSuT
# #92 date/time: 2018-10-19/15:39:21 country: GB coords: [1.061326, 52.581316]
# sentiment: {'score': 0.0766988, 'label': 'positive'} emotion: {'sadness': 0.103269, 'joy': 0.302554, 'anger': 0.309172, 'disgust': 0.180849, 'fear': 0.140302}
# text: Silly boy! You have your councillor asking you for your questions. Make an appointment, go and see him! He is entit… https://t.co/JKD48c3ES8
# #93 date/time: 2018-10-19/15:40:16 country: GB coords: [-1.7331064999999999, 54.9048415]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.08427, 'joy': 0.501021, 'anger': 0.323809, 'disgust': 0.028243, 'fear': 0.065435}
# text: His lovchild ukip of course being pure as the driven snow. How they drifted.
# #94 date/time: 2018-10-19/15:40:52 country: GB coords: [-1.447629, 54.818312]
# sentiment: {'score': 0.582573, 'label': 'positive'} emotion: {'sadness': 0.150618, 'joy': 0.381108, 'anger': 0.062394, 'disgust': 0.379737, 'fear': 0.107686}
# text: @bbcquestiontime Spot on!! Take note @UKLabour and @Conservatives this is bigger than party politics &amp; we the peopl… https://t.co/Oc5pmfEB2q
# #95 date/time: 2018-10-19/15:41:26 country: GB coords: [-1.2074825, 53.9318445]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.193334, 'joy': 0.270309, 'anger': 0.271555, 'disgust': 0.407588, 'fear': 0.118987}
# text: Some silly lady on Sky News this morning was saying this was a disaster for British farming on the brink of BrExit… https://t.co/trDtZvnlDH
# #96 date/time: 2018-10-19/15:41:30 country: FR coords: [-3.9865565, 48.713398500000004]
# sentiment: {} emotion: {}
# text: 🛳️En dépit d'une saison estivale 2018 satisfaisante, la @BrittanyFerries reste vigilante sur le sujet du #Brexit :… https://t.co/PlmYKcdD2n
# #97 date/time: 2018-10-19/15:41:36 country: GB coords: [-1.3090495, 53.593569]
# sentiment: {'score': -0.948864, 'label': 'negative'} emotion: {'sadness': 0.62242, 'joy': 0.006353, 'anger': 0.393788, 'disgust': 0.140023, 'fear': 0.178907}
# text: What an awful piece of writing, drowning in cliches and simplifications. No reference whatsoever to the argument th… https://t.co/PmfUsun7Uh
# #98 date/time: 2018-10-19/15:41:43 country: GB coords: [-2.965561, 51.617475999999996]
# sentiment: {'score': 0.702511, 'label': 'positive'} emotion: {'sadness': 0.212097, 'joy': 0.557735, 'anger': 0.114688, 'disgust': 0.037157, 'fear': 0.065515}
# text: Says rich person, Michael Caine. As long as you’re alright, pal, I’ll rest easy.
# #99 date/time: 2018-10-19/15:41:44 country: GB coords: [0.2515055, 51.142153]
# sentiment: {'score': 0.614021, 'label': 'positive'} emotion: {'sadness': 0.201226, 'joy': 0.627465, 'anger': 0.043234, 'disgust': 0.020237, 'fear': 0.07459}
# text: @Femi_Sorry Mike is definitely a believer of the greater good that brexit might deliver after his death and most li… https://t.co/DrzqPsJXFK
# #100 date/time: 2018-10-19/15:42:03 country: RE coords: [55.44444250000001, -20.9433855]
# sentiment: {} emotion: {}
# text: #Brexit : le spectre de nouvelles élections plane sur #TheresaMay - https://t.co/kRMNsj7sPQ https://t.co/umydxdFvgi
# #101 date/time: 2018-10-19/15:42:47 country: GB coords: [-4.0016169999999995, 52.404436000000004]
# sentiment: {'score': 0.814926, 'label': 'positive'} emotion: {'sadness': 0.062845, 'joy': 0.691685, 'anger': 0.124035, 'disgust': 0.053748, 'fear': 0.019036}
# text: @OFOCBrexit @Femi_Sorry This is an excellent point and one that I was unaware of but will add to my arsenal of coun… https://t.co/No11syyn9R
# #102 date/time: 2018-10-19/15:42:49 country: GB coords: [-1.1978615000000001, 53.564814]
# sentiment: {'score': -0.89027, 'label': 'negative'} emotion: {'sadness': 0.358558, 'joy': 0.141537, 'anger': 0.141402, 'disgust': 0.212503, 'fear': 0.033715}
# text: ...and how patronising to Brexit voters to suggest that they have tiny attention spans and no ongoing interest in politics.
# #103 date/time: 2018-10-19/15:42:55 country: GB coords: [0.5115780000000001, 52.2204505]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.35904, 'joy': 0.030821, 'anger': 0.054212, 'disgust': 0.096062, 'fear': 0.068988}
# text: If we leave the SM we can kiss goodbye to Nissan, Toyota and Honda manufacturing cars in the U.K. personally I hope… https://t.co/fClfHDlplj
# #104 date/time: 2018-10-19/15:43:56 country: GB coords: [-1.8906405, 52.4939665]
# sentiment: {'score': -0.707703, 'label': 'negative'} emotion: {'sadness': 0.103463, 'joy': 0.079578, 'anger': 0.520321, 'disgust': 0.544508, 'fear': 0.050254}
# text: @SkyNewsBreak #nickclegg , the man who fucked over the students, Enabled the #austerityscam  &amp; stirred up the anti… https://t.co/Zoe7KnzKXr
# #105 date/time: 2018-10-19/15:44:18 country: GB coords: [-0.8415085, 51.408120499999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.386214, 'joy': 0.156855, 'anger': 0.13684, 'disgust': 0.086053, 'fear': 0.097564}
# text: @NyseriA @Iromg @tomamason @talkRADIO @DawnNeesom @Femi_Sorry @OFOCBrexit @Nasdaq Dear @lromg Mike,
#
# This is how… https://t.co/MmpdQRkGaH
# #106 date/time: 2018-10-19/15:44:32 country: GB coords: [0.317777, 51.4864855]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.148831, 'joy': 0.179551, 'anger': 0.088473, 'disgust': 0.074744, 'fear': 0.091248}
# text: Or no brexit
# #107 date/time: 2018-10-19/15:44:34 country: GB coords: [-0.19371950000000002, 51.4516565]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.113225, 'joy': 0.74624, 'anger': 0.077376, 'disgust': 0.028475, 'fear': 0.0334}
# text: @KateHoeyMP But did you read that he will be “moving to California permanently in the new year”?  There’s a silver… https://t.co/FbJ2lDut5H
# #108 date/time: 2018-10-19/15:44:36 country: HU coords: [19.129828, 47.4812305]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.393748, 'joy': 0.09707, 'anger': 0.134144, 'disgust': 0.052491, 'fear': 0.144766}
# text: @symmo1969 @Harryslaststand And as soon as it becomes clear that franchises will be removed at the end of the term.… https://t.co/O3cniIk8cM
# #109 date/time: 2018-10-19/15:44:41 country: US coords: [-118.4119065, 34.0207895]
# sentiment: {'score': -0.564017, 'label': 'negative'} emotion: {'sadness': 0.411498, 'joy': 0.031016, 'anger': 0.281206, 'disgust': 0.242473, 'fear': 0.384242}
# text: @_pallavighosh @bainjal i heard she got some award . i dnt know whats wrong with British ppl, they have not taken… https://t.co/0NGEbKTn2t
# #110 date/time: 2018-10-19/15:44:50 country: GB coords: [-1.4072875, 53.522229499999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text: https://t.co/sqsKSXDUpa
# #111 date/time: 2018-10-19/15:45:42 country: US coords: [-88.1425115, 41.519555999999994]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.217966, 'joy': 0.175226, 'anger': 0.262398, 'disgust': 0.417157, 'fear': 0.159157}
# text: #Brexit debate this week
# #112 date/time: 2018-10-19/15:45:50 country: GB coords: [-1.2074825, 53.9318445]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.31132, 'joy': 0.166054, 'anger': 0.007742, 'disgust': 0.314794, 'fear': 0.188531}
# text: @AaronBastani Confirming that Labour is a pro Brexit party.
# #113 date/time: 2018-10-19/15:46:15 country: GB coords: [-1.8900305, 53.729573]
# sentiment: {'score': -0.559331, 'label': 'negative'} emotion: {'sadness': 0.366877, 'joy': 0.098935, 'anger': 0.393275, 'disgust': 0.237236, 'fear': 0.042015}
# text: I don't know the answer to that question but they obviously care little for the thousands of French people that liv… https://t.co/gxE9mjghb0
# #114 date/time: 2018-10-19/15:46:17 country: GB coords: [-0.8415085, 51.408120499999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.489422, 'joy': 0.070823, 'anger': 0.339823, 'disgust': 0.077059, 'fear': 0.11082}
# text: @NyseriA @Iromg @tomamason @talkRADIO @DawnNeesom @Femi_Sorry @OFOCBrexit Dear @NyseriA
#
# Did I ask you if you pay… https://t.co/SWcbPWaJyt
# #115 date/time: 2018-10-19/15:46:40 country: GB coords: [-2.8948824999999996, 53.1973495]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.480877, 'joy': 0.336284, 'anger': 0.003227, 'disgust': 0.082624, 'fear': 0.064334}
# text: "Squatting to curl his daily telegraph column"😂
# #116 date/time: 2018-10-19/15:46:42 country: GB coords: [-0.0601675, 51.547644500000004]
# sentiment: {'score': 0.461335, 'label': 'positive'} emotion: {'sadness': 0.422034, 'joy': 0.103273, 'anger': 0.02604, 'disgust': 0.245574, 'fear': 0.155339}
# text: A left populist strategy is the way forward for Labour @Keir_Starmer @jon_trickett @EklundhEmmy @G_Katsambekis  https://t.co/5ryQuvKtTt
# #117 date/time: 2018-10-19/15:47:07 country: IE coords: [-6.23572, 53.494597999999996]
# sentiment: {'score': 0.575198, 'label': 'positive'} emotion: {'sadness': 0.252877, 'joy': 0.327598, 'anger': 0.057866, 'disgust': 0.183566, 'fear': 0.130662}
# text: @Iannic @unherd @giles_fraser If you read the article properly you will read that the article concludes that it is… https://t.co/uatgAiY0Hd
# #118 date/time: 2018-10-19/15:47:17 country: GB coords: [-3.2030085, 55.9431955]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.165368, 'joy': 0.333244, 'anger': 0.06505, 'disgust': 0.340366, 'fear': 0.065335}
# text: Victory? The 20% brigade will need to rig those votes on a big scale
# #119 date/time: 2018-10-19/15:47:24 country: GB coords: [-2.7280515, 51.203098499999996]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.689683, 'joy': 0.018993, 'anger': 0.259622, 'disgust': 0.200198, 'fear': 0.053635}
# text: @emmyzen @mvanderKist 1975 was the proper and DEMOCRATIC election to be in EUROPE get used to it Brexit losers now… https://t.co/oJxwPtYSR7
# #120 date/time: 2018-10-19/15:47:25 country: NL coords: [5.749013499999999, 52.0715855]
# sentiment: {} emotion: {}
# text: Dit weekend echt doen en vertel me wat #Gelderland voor uw #bedrijf kan doen: #werk maken van #opengrenzen
# #121 date/time: 2018-10-19/15:47:32 country: GB coords: [-0.11540600000000001, 51.4603395]
# sentiment: {'score': 0.235092, 'label': 'positive'} emotion: {'sadness': 0.169016, 'joy': 0.590002, 'anger': 0.155468, 'disgust': 0.046035, 'fear': 0.068055}
# text: Want to stop Brexit? Then tomorrow's march is a great way to show you care. Join me and thousands of @LibDems.
#
# Det… https://t.co/dqCmrk41yj
# #122 date/time: 2018-10-19/15:48:05 country: GB coords: [-1.4072875, 53.522229499999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text: https://t.co/S5gO23ji1S
# #123 date/time: 2018-10-19/15:48:38 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {'score': -0.679026, 'label': 'negative'} emotion: {'sadness': 0.561997, 'joy': 0.024906, 'anger': 0.325651, 'disgust': 0.130092, 'fear': 0.207868}
# text: @DrAdrianHeald I suppose the fact the PM of Lithuania was the only one pointing out the nonsense of the UK's positi… https://t.co/DBXcVMIMqf
# #124 date/time: 2018-10-19/15:50:21 country: GB coords: [-7.0250755, 55.04369749999999]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.428491, 'joy': 0.091216, 'anger': 0.061021, 'disgust': 0.149724, 'fear': 0.203645}
# text: @duncy_p @ThomasEvansSDP @kenty227 @bbcquestiontime And tourism def affected.
# Here in N.I. I know tourists/B&amp;B's et… https://t.co/vs66Rvlxn9
# #125 date/time: 2018-10-19/15:51:13 country: GB coords: [0.5277305, 51.26357900000001]
# sentiment: {'score': -0.614721, 'label': 'negative'} emotion: {'sadness': 0.312877, 'joy': 0.047577, 'anger': 0.575525, 'disgust': 0.241759, 'fear': 0.143522}
# text: FFS, this is not “all about feelings”. What an idiotic thing to say. https://t.co/DRWKhUAzeL
# #126 date/time: 2018-10-19/15:51:17 country: GB coords: [-3.2030085, 55.9431955]
# sentiment: {'score': 0.647642, 'label': 'positive'} emotion: {'sadness': 0.15867, 'joy': 0.286177, 'anger': 0.091395, 'disgust': 0.051587, 'fear': 0.175473}
# text: @killicktw @CS6543 @bbcthisweek @afneil @ScreamOfficial Too strong for them .... I think maybe they're just not qui… https://t.co/sotBrR9rwq
# #127 date/time: 2018-10-19/15:51:28 country: GB coords: [-0.017990000000000006, 51.454107]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text: https://t.co/ecZaskDPhl
# #128 date/time: 2018-10-19/15:51:41 country: GB coords: [-0.0706035, 51.464686]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.180629, 'joy': 0.207557, 'anger': 0.189468, 'disgust': 0.275616, 'fear': 0.314575}
# text: .@CarolineFlintMP absolutely lays down the law to @campbellclaret on #bbtw on brexit
# #129 date/time: 2018-10-19/15:52:04 country: US coords: [-89.5694915, 44.900818]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.154597, 'joy': 0.138079, 'anger': 0.097507, 'disgust': 0.086178, 'fear': 0.078431}
# text: Brexit II: Electric Boogaloo
# #130 date/time: 2018-10-19/15:52:05 country: GB coords: [-2.3807945, 53.772616]
# sentiment: {'score': 0.695416, 'label': 'positive'} emotion: {'sadness': 0.036738, 'joy': 0.812923, 'anger': 0.052925, 'disgust': 0.017682, 'fear': 0.068064}
# text: BCC: Ease Brexit uncertainty to boost innovation through trade https://t.co/de6lIZdNVU https://t.co/sbTQlsbBwW
# #131 date/time: 2018-10-19/15:52:16 country: GB coords: [0.317777, 51.4864855]
# sentiment: {'score': -0.85626, 'label': 'negative'} emotion: {'sadness': 0.641453, 'joy': 0.02466, 'anger': 0.303115, 'disgust': 0.297717, 'fear': 0.026813}
# text: Despite what @suzanne_moore says about 'has been' politicians in her unpleasant 'Remainers are elitist' piece today… https://t.co/5oMNLOvToE
# #132 date/time: 2018-10-19/15:52:42 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': -0.943432, 'label': 'negative'} emotion: {'sadness': 0.446323, 'joy': 0.002318, 'anger': 0.663175, 'disgust': 0.106803, 'fear': 0.097751}
# text: @MrStu10 this is your fault..... upsetting poch
# #133 date/time: 2018-10-19/15:52:48 country: GB coords: [-1.0750485, 53.504823]
# sentiment: {'score': 0.793205, 'label': 'positive'} emotion: {'sadness': 0.318556, 'joy': 0.065997, 'anger': 0.129551, 'disgust': 0.549949, 'fear': 0.115139}
# text: @Peston @AbortBrexit @Jeremy_Hunt @theresa_may Mr Hunt &amp; Gov need to be very careful. The country is massively divi… https://t.co/xIzSF0GvMx
# #134 date/time: 2018-10-19/15:52:58 country: GB coords: [-2.823758, 51.580605999999996]
# sentiment: {'score': -0.819979, 'label': 'negative'} emotion: {'sadness': 0.038293, 'joy': 0.110288, 'anger': 0.782724, 'disgust': 0.105395, 'fear': 0.017163}
# text: At this present time, somebody is scrolling through his timeline to find every angry utterance on Glenn Hoddle.
# #135 date/time: 2018-10-19/15:53:05 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {'score': -0.0731044, 'label': 'negative'} emotion: {'sadness': 0.541082, 'joy': 0.009814, 'anger': 0.273943, 'disgust': 0.347383, 'fear': 0.179054}
# text: If you don’t laugh you could cry. Glad police removed quickly. In seriousness though report all hate crime &amp; incide… https://t.co/6Dpxa5ks5O
# #136 date/time: 2018-10-19/15:53:08 country: GR coords: [23.411256, 40.050103]
# sentiment: {'score': -0.312839, 'label': 'negative'} emotion: {'sadness': 0.313546, 'joy': 0.411049, 'anger': 0.097286, 'disgust': 0.075529, 'fear': 0.095743}
# text: #Brexit Where and when will all this end so we can all get on with life and have a degree of certainty. We don't kn… https://t.co/pX6dlrqiSz
# #137 date/time: 2018-10-19/15:53:15 country: IE coords: [-6.399521, 53.2735025]
# sentiment: {'score': 0.468274, 'label': 'positive'} emotion: {'sadness': 0.16563, 'joy': 0.179249, 'anger': 0.076849, 'disgust': 0.140977, 'fear': 0.088487}
# text: Merkel 'unequivocally' supports Ireland over Brexit https://t.co/9geETjS9AO
# #138 date/time: 2018-10-19/15:53:16 country: GB coords: [-3.2030085, 55.9431955]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.291381, 'joy': 0.256547, 'anger': 0.370665, 'disgust': 0.053242, 'fear': 0.048358}
# text: The @Conservatives could use Section 12 of the European Union Withdrawal Act essentially as a power grab.
#
# The omn… https://t.co/kq0G4uX3lZ
# #139 date/time: 2018-10-19/15:54:40 country: GB coords: [-3.3829115, 51.5318705]
# ...
# #8351 date/time: 2018-10-21/14:14:26 country: ES coords: [2.006363, 41.582976]
# sentiment: {} emotion: {}
# text: Aquestes persones que diuen que una manifestació sobre el Brexit de 700.000 persones en un país de 60 milions d'hab… https://t.co/ZDUCRRLZb4
# #8352 date/time: 2018-10-21/14:14:33 country: GB coords: [-0.445072, 51.6510705]
# sentiment: {'score': -0.329549, 'label': 'negative'} emotion: {'sadness': 0.715107, 'joy': 0.068026, 'anger': 0.107969, 'disgust': 0.252013, 'fear': 0.021214}
# text: @DanielJHannan Once again David Lammy supports LOSERS. How can this country be great again when being a loser is so… https://t.co/iYbju5ZDFS
# #8353 date/time: 2018-10-21/14:14:45 country: GB coords: [-3.4468685, 55.012153]
# sentiment: {'score': -0.485961, 'label': 'negative'} emotion: {'sadness': 0.096019, 'joy': 0.038844, 'anger': 0.164367, 'disgust': 0.12574, 'fear': 0.789375}
# text: @Anna_Soubry How #Brexit poses a threat to British sovereignty.
#
# https://t.co/VsGXXjZeXE
# #8354 date/time: 2018-10-21/14:14:53 country: US coords: [-83.1738665, 32.6782075]
# sentiment: {'score': 0.515102, 'label': 'positive'} emotion: {'sadness': 0.393442, 'joy': 0.210672, 'anger': 0.046162, 'disgust': 0.018602, 'fear': 0.181811}
# text: @AlexDSAvery @StephenHotHands @DLoesch That’s your problem you think elites are smart so they should rule common pe… https://t.co/MaNKrebJds
# #8355 date/time: 2018-10-21/14:15:03 country: US coords: [-71.0887125, 42.3136695]
# sentiment: {} emotion: {}
# text: ...
# #8356 date/time: 2018-10-21/14:15:16 country: ES coords: [2.006363, 41.582976]
# sentiment: {} emotion: {}
# text: Aquestes persones que diuen que una manifestació sobre el Brexit de 700.000 persones en un país de 60 milions d'hab… https://t.co/Thed86UzS9
# #8357 date/time: 2018-10-21/14:15:26 country: UA coords: [31.181446, 48.382929]
# sentiment: {'score': -0.405335, 'label': 'negative'} emotion: {'sadness': 0.47846, 'joy': 0.099333, 'anger': 0.178396, 'disgust': 0.259467, 'fear': 0.072174}
# text: No, people voted for the pledge to divert £350 million a week from the EU into the NHS. And similar lies #Brexit… https://t.co/JlfHdXHYSt
# #8358 date/time: 2018-10-21/14:15:38 country: GB coords: [-4.2417514999999995, 55.85830249999999]
# sentiment: {'score': 0.510267, 'label': 'positive'} emotion: {'sadness': 0.097616, 'joy': 0.230067, 'anger': 0.068737, 'disgust': 0.087866, 'fear': 0.049959}
# text: @francisr829 @Deanowasking @ThatGuyAkshay @nigel_callaghan @britainelects @KantarTNS True but Corbyn is arguable ev… https://t.co/Ko1abVlkZk
# #8359 date/time: 2018-10-21/14:15:39 country: CL coords: [-72.96850099999999, -36.8421855]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.073132, 'joy': 0.035288, 'anger': 0.184788, 'disgust': 0.045308, 'fear': 0.034329}
# text: Brexit: "lassitude" et "frustration" gagnent l'Irlande du Nord - https://t.co/ScBGL0yQUH https://t.co/qX1wb4Wp6x
# #8360 date/time: 2018-10-21/14:16:06 country: GB coords: [-2.915427, 53.4198785]
# sentiment: {'score': -0.4205, 'label': 'negative'} emotion: {'sadness': 0.213545, 'joy': 0.524908, 'anger': 0.042481, 'disgust': 0.294888, 'fear': 0.034047}
# text: Dead good this. Nails the mindset of the whole backwards movement.
#
# “They believe Britain (by which they really me… https://t.co/FmIRaH8OAO
# #8361 date/time: 2018-10-21/14:16:12 country: GB coords: [-0.4608105, 51.8375695]
# sentiment: {'score': -0.650753, 'label': 'negative'} emotion: {'sadness': 0.507966, 'joy': 0.09334, 'anger': 0.093033, 'disgust': 0.17319, 'fear': 0.104178}
# text: @jimmygee51 James I have no idea. All I do know is we are running out of time, and Brexit is already damaging the country.
# #8362 date/time: 2018-10-21/14:17:17 country: GB coords: [-2.202075, 53.548435999999995]
# sentiment: {'score': -0.7854, 'label': 'negative'} emotion: {'sadness': 0.199597, 'joy': 0.140389, 'anger': 0.093942, 'disgust': 0.149238, 'fear': 0.074897}
# text: @bbcnickrobinson @KarenDanczuk Brexit means Brexit nick so this protest won't achieve anything
# #8363 date/time: 2018-10-21/14:18:30 country: GB coords: [-1.873717, 50.876778]
# sentiment: {'score': -0.423571, 'label': 'negative'} emotion: {'sadness': 0.13747, 'joy': 0.090495, 'anger': 0.243412, 'disgust': 0.25889, 'fear': 0.364201}
# text: Perhaps @Andrew_Adonis could republish the leaflet so that we can all be certain of what was said. I think I must h… https://t.co/Fk5OYo7KxO
# #8364 date/time: 2018-10-21/14:18:44 country: GB coords: [-0.21089449999999998, 51.6118845]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.190976, 'joy': 0.267753, 'anger': 0.146572, 'disgust': 0.096842, 'fear': 0.130928}
# text: @jonie1303 @maria_norwich @JamesMelville here's the thing, and there's no getting away from this, Brexit is a racis… https://t.co/nWhU1ye0jM
# #8365 date/time: 2018-10-21/14:18:44 country: FR coords: [3.37071, 43.502973]
# sentiment: {'score': 0.87522, 'label': 'positive'} emotion: {'sadness': 0.082744, 'joy': 0.801837, 'anger': 0.045041, 'disgust': 0.016885, 'fear': 0.005905}
# text: How interesting to see wonderful @AirbusintheUK continuing its investments and partnerships despite, er, #brexit
# #8366 date/time: 2018-10-21/14:18:46 country: GB coords: [-3.4468685, 55.012153]
# sentiment: {'score': -0.485961, 'label': 'negative'} emotion: {'sadness': 0.096019, 'joy': 0.038844, 'anger': 0.164367, 'disgust': 0.12574, 'fear': 0.789375}
# text: @CatherineWest1 @OwenSmith_MP @Kevin_Maguire How #Brexit poses a threat to British sovereignty.
#
# https://t.co/VsGXXjZeXE
# #8367 date/time: 2018-10-21/14:20:03 country: GB coords: [-0.0706035, 51.464686]
# sentiment: {'score': -0.662156, 'label': 'negative'} emotion: {'sadness': 0.7303, 'joy': 0.049284, 'anger': 0.152351, 'disgust': 0.04994, 'fear': 0.225731}
# text: Moving forward and making progress to crash the economy, lose jobs and trigger rise in interest rates affecting mor… https://t.co/W7vAkMfzUH
# #8368 date/time: 2018-10-21/14:20:23 country: NL coords: [4.4816935, 52.151743499999995]
# sentiment: {'score': -0.586645, 'label': 'negative'} emotion: {'sadness': 0.158859, 'joy': 0.177287, 'anger': 0.232805, 'disgust': 0.046139, 'fear': 0.111574}
# text: @Charlie_uk45 @haydnandrew @JamessReality @RobertaBuchan1 It's all one market, Charlie. No UK car has more than 41%… https://t.co/ZodDsfvm5K
# #8369 date/time: 2018-10-21/14:20:36 country: GB coords: [-2.1556405, 53.4146085]
# sentiment: {'score': 0.915948, 'label': 'positive'} emotion: {'sadness': 0.004581, 'joy': 0.884137, 'anger': 0.011282, 'disgust': 0.048756, 'fear': 0.058422}
# text: Hahaha!!! Love that!!! 👏👏👏👏
# #8370 date/time: 2018-10-21/14:21:25 country: GB coords: [-3.9847479999999997, 55.8013465]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.16538, 'joy': 0.26938, 'anger': 0.087168, 'disgust': 0.085631, 'fear': 0.070171}
# text: @giles_fraser The marchers yesterday represented a much larger number of people dissatisfied with the Brexit on the… https://t.co/5nHOiY9z2z
# #8371 date/time: 2018-10-21/14:21:48 country: GB coords: [-0.2527539999999999, 51.3854455]
# sentiment: {'score': 0.670042, 'label': 'positive'} emotion: {'sadness': 0.076332, 'joy': 0.156448, 'anger': 0.037042, 'disgust': 0.254617, 'fear': 0.61479}
# text: @GHNeale Hopefully not in some post Brexit apocalyptic dystopian landscape, brawling for possession of the last cauliflower in captivity 😱😱😱
# #8372 date/time: 2018-10-21/14:21:52 country: US coords: [-84.48162649999999, 42.746719999999996]
# sentiment: {'score': -0.66875, 'label': 'negative'} emotion: {'sadness': 0.320767, 'joy': 0.027658, 'anger': 0.286524, 'disgust': 0.443445, 'fear': 0.213832}
# text: “Brexit” is an awful celebrity couple name if you ask me
# #8373 date/time: 2018-10-21/14:22:37 country: GB coords: [0.135916, 52.200974]
# sentiment: {'score': 0.599542, 'label': 'positive'} emotion: {'sadness': 0.179054, 'joy': 0.396934, 'anger': 0.041349, 'disgust': 0.117782, 'fear': 0.126987}
# text: A handy graphic to show the difference in scale between the #PeoplesVoteMarch in London and the Save Brexit Rally i… https://t.co/qh9DJHQ99C
# #8374 date/time: 2018-10-21/14:23:07 country: GR coords: [24.508861, 38.2752785]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.264728, 'joy': 0.279425, 'anger': 0.163226, 'disgust': 0.080403, 'fear': 0.098099}
# text: @Lee_One_Pen @BernadetteC23 @jessphillips This was always the objective. Hitler did the same thing after the 1929 W… https://t.co/u0IqGvr6KT
# #8375 date/time: 2018-10-21/14:23:25 country: GB coords: [-1.9654690000000001, 51.7145185]
# sentiment: {'score': -0.634615, 'label': 'negative'} emotion: {'sadness': 0.304271, 'joy': 0.275339, 'anger': 0.10283, 'disgust': 0.383363, 'fear': 0.140671}
# text: Officials play 'war games' on a second referendum on Brexit https://t.co/FfA5nNyObU via @MailOnline even if there w… https://t.co/54J3UA8b4E
# #8376 date/time: 2018-10-21/14:23:40 country: GB coords: [-1.315112, 50.8868545]
# sentiment: {'score': -0.733852, 'label': 'negative'} emotion: {'sadness': 0.618872, 'joy': 0.025545, 'anger': 0.078924, 'disgust': 0.44102, 'fear': 0.082342}
# text: @jeremycorbyn has let us labour supporters down, he has lost any chance of getting in at no10 with his Brexit stanc… https://t.co/WDNl5frYgi
# #8377 date/time: 2018-10-21/14:23:43 country: GB coords: [-0.0706035, 51.464686]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.141119, 'joy': 0.148761, 'anger': 0.136999, 'disgust': 0.09352, 'fear': 0.049992}
# text: #spizzart #brexit #cartoon #hourglass @ Bermondsey https://t.co/uY4AEzgnHf
# #8378 date/time: 2018-10-21/14:23:57 country: GB coords: [-1.396467, 50.921327500000004]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.237337, 'joy': 0.222622, 'anger': 0.11692, 'disgust': 0.137536, 'fear': 0.103801}
# text: @markjpalmer78 @campbellclaret Otherwise knows as facts... https://t.co/NVJF9AJuvP
# #8379 date/time: 2018-10-21/14:24:03 country: GB coords: [-2.5194485, 53.4230175]
# sentiment: {'score': -0.906658, 'label': 'negative'} emotion: {'sadness': 0.505982, 'joy': 0.022423, 'anger': 0.172756, 'disgust': 0.561466, 'fear': 0.049621}
# text: @HardingMike @PamCrossland Sadly, Brexit was won on a protest vote by these very people. That's the very group, the… https://t.co/nfoyDrSxrW
# #8380 date/time: 2018-10-21/14:24:06 country: FR coords: [2.347003, 48.8588335]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.166772, 'joy': 0.551041, 'anger': 0.062698, 'disgust': 0.048389, 'fear': 0.053106}
# text: Barnier making the point that there already are some checks on goods between mainland Britain and Northern Ireland,… https://t.co/BSBESAuatF
# #8381 date/time: 2018-10-21/14:24:21 country: DO coords: [-70.0087115, 18.4680185]
# sentiment: {} emotion: {}
# text: https://t.co/mwCpWyvH22 ¿Qué paso con David Cameron, el político que nos metió en el lío del “Brexit”?
# #8382 date/time: 2018-10-21/14:24:28 country: DE coords: [6.891947, 51.318180999999996]
# sentiment: {} emotion: {}
# text: @ZDFheute @tagesschau Was für eine Welt? Wieso wird der Mann nicht umgehend des Flugzeugs verwiesen? Wie kann eine… https://t.co/Y838RN5Uqx
# #8383 date/time: 2018-10-21/14:24:48 country: GB coords: [-0.19371950000000002, 51.4516565]
# sentiment: {'score': -0.0340369, 'label': 'negative'} emotion: {'sadness': 0.349717, 'joy': 0.373664, 'anger': 0.248269, 'disgust': 0.043132, 'fear': 0.016319}
# text: @guidoacasa Good for you Dunks. But rest assured, nothing you say, especially quoting pointless stats, will change my mind about brexit
# #8384 date/time: 2018-10-21/14:24:52 country: GB coords: [-3.5995935, 55.9760105]
# sentiment: {} emotion: {}
# text: @ScotsKat Brexit McBrexitface?
# #8385 date/time: 2018-10-21/14:24:59 country: GB coords: [-3.008336, 56.317652499999994]
# sentiment: {'score': -0.447825, 'label': 'negative'} emotion: {'sadness': 0.286078, 'joy': 0.049775, 'anger': 0.199817, 'disgust': 0.329709, 'fear': 0.184473}
# text: These CLOWNS can't see any further than the end of their noses if Eire can do Scotland can surely. Do it just more… https://t.co/EXTrL54fHL
# #8386 date/time: 2018-10-21/14:25:16 country: DO coords: [-70.0087115, 18.4680185]
# sentiment: {} emotion: {}
# text: https://t.co/A4JbRPbirH Brexit: 80% de empresas británicas critica la incertidumbre
# #8387 date/time: 2018-10-21/14:25:36 country: GB coords: [-3.3391260000000003, 55.8796085]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.295371, 'joy': 0.119645, 'anger': 0.30005, 'disgust': 0.180513, 'fear': 0.043396}
# text: Once again I ask the question, what's with the Greens obsession, with indyref2?
# #8388 date/time: 2018-10-21/14:25:41 country: GB coords: [-4.032997, 50.8916465]
# sentiment: {'score': -0.642119, 'label': 'negative'} emotion: {'sadness': 0.418168, 'joy': 0.035126, 'anger': 0.146609, 'disgust': 0.646496, 'fear': 0.032037}
# text: @UKIP Bunch of grey haired, red faced, racist old dinosaurs completely dismissing 600,000 young voters. This is why… https://t.co/RsJx0dSXGY
# #8389 date/time: 2018-10-21/14:25:52 country: DO coords: [-70.0087115, 18.4680185]
# sentiment: {} emotion: {}
# text: https://t.co/A4JbRPbirH Brexit: 80% de empresas británicas critica la incertidumbre
# #8390 date/time: 2018-10-21/14:26:14 country: GB coords: [1.2730815, 52.641482999999994]
# sentiment: {'score': -0.538018, 'label': 'negative'} emotion: {'sadness': 0.194369, 'joy': 0.092951, 'anger': 0.324124, 'disgust': 0.087022, 'fear': 0.128366}
# text: @Laugh_Exchange Ello… are you US only? Trying to connect from the UK. Humour may be our only viable export post-Bre… https://t.co/BGpIgxceDt
# #8391 date/time: 2018-10-21/14:26:20 country: GB coords: [-1.396467, 50.921327500000004]
# sentiment: {'score': -0.396193, 'label': 'negative'} emotion: {'sadness': 0.551411, 'joy': 0.074375, 'anger': 0.194097, 'disgust': 0.097, 'fear': 0.105867}
# text: Otherwise known as facts...
# https://t.co/NVJF9AJuvP
# Nobody mentioned religion...
#
# Do Leave campaigners get triggere… https://t.co/L1WaIyfPZM
# #8392 date/time: 2018-10-21/14:26:36 country: DO coords: [-70.0087115, 18.4680185]
# sentiment: {} emotion: {}
# text: https://t.co/fP48sUUrqa La ley de Murphy y el "brexit"
# #8393 date/time: 2018-10-21/14:26:36 country: GB coords: [-1.76682, 53.8159335]
# sentiment: {'score': -0.822423, 'label': 'negative'} emotion: {'sadness': 0.195072, 'joy': 0.015567, 'anger': 0.73858, 'disgust': 0.23227, 'fear': 0.08994}
# text: @jeremycorbyn so where the fuck were you yesterday you phoney?
# #8394 date/time: 2018-10-21/14:26:39 country: GB coords: [-0.2708845, 51.94962]
# sentiment: {'score': -0.702449, 'label': 'negative'} emotion: {'sadness': 0.477396, 'joy': 0.056595, 'anger': 0.100295, 'disgust': 0.099445, 'fear': 0.157898}
# text: Im not even able to list every atrocity that Britain committed in the name of the ‘Empire’…
#
# Unbelievable how litt… https://t.co/95IpZcDbqK
# #8395 date/time: 2018-10-21/14:26:44 country: IE coords: [-6.23572, 53.494597999999996]
# sentiment: {} emotion: {}
# text: 👏👏👏👏
# #8396 date/time: 2018-10-21/14:26:58 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.064035, 'joy': 0.574412, 'anger': 0.13018, 'disgust': 0.080319, 'fear': 0.123378}
# text: Jamón Jamón not Gammon Gammon #peoplesvote #brexit #jamonnotgammon #exitbrexit #brexshit @ Hyde Park https://t.co/YLXbf1f1cj
# #8397 date/time: 2018-10-21/14:27:08 country: GB coords: [-0.055730999999999996, 51.718321]
# sentiment: {'score': 0.462048, 'label': 'positive'} emotion: {'sadness': 0.045679, 'joy': 0.463894, 'anger': 0.059575, 'disgust': 0.195257, 'fear': 0.028843}
# text: @pitcombe Well no talk of Brexit must be a bonus
# #8398 date/time: 2018-10-21/14:27:25 country: GB coords: [0.20585499999999998, 52.186064]
# sentiment: {'score': -0.482626, 'label': 'negative'} emotion: {'sadness': 0.346629, 'joy': 0.183527, 'anger': 0.214248, 'disgust': 0.251364, 'fear': 0.222727}
# text: @unionlib @ClareFKing How do you feel about Attlee serving under Churchill in the War? Should he have said no for i… https://t.co/y6yAJdOO2H

# %%
result_collection = Result(tweets_database.all_docs, include_docs=True)
print("Retrieved minimal document:\n{0}\n".format(result_collection[0]))
# Out:
# Retrieved minimal document:
# [{'id': '0101029b49763406b302b25b3f1e3a1d', 'doc': {'_id': '0101029b49763406b302b25b3f1e3a1d', 'geometry': {'coordinates': [4.2716075, 51.9244575], 'type': 'Point'}, '_rev': '1-7ea1fc1e33756fbd1952f8e7db39b520', 'timeCreated': '04:01:56', 'dateCreated': '2018-10-19', 'text': 'Brexit\n\nHet levert vast\nEen ijzersterke\nBbc documentaire\nOp\n\nLoesje @ Rotterdam, Netherlands https://t.co/y0XwerzdNu', 'type': 'Feature', 'sentiment': {}, 'country': 'NL', 'emotion': {}}, 'value': {'rev': '1-7ea1fc1e33756fbd1952f8e7db39b520'}, 'key': '0101029b49763406b302b25b3f1e3a1d'}]

# %%
tweet_emotion
# Out:
# {'anger': 0.121029,
#  'disgust': 0.083401,
#  'fear': 0.065787,
#  'joy': 0.304163,
#  'sadness': 0.101967}

# %%
tweet_sentiment
# Out:
# {'label': 'positive', 'score': 0.922588}

# %%
from cloudant import index
index_name="_design/geodd"
index_definition= {
    "_id":index_name,
    "views":{},
    "language": "javascript",
    "st_indexes": {
    "geoidx": {"function (doc) {if (doc.geometry && doc.geometry.coordinates) {st_index(doc.geometry);}}"
}}}
tweets_index = index.Index(tweets_database, )

# %%
place_bbox = [[],[],[],[]]

# %%
place_bbox =[12,4,3]
set_db_name(["brexit", "test, try"], ['GB', 'IE'], place_bbox)
# Out:
# 'brexit_test&try_gb_ie_12_4_3'

# %%
place_bbox =[]

# %%
''.join(str(place_bbox)).replace(', ','_').replace('[','').replace(']','')
# Out:
# ''

# %%
'GB' in ['GB', 'IE']
# Out:
# True
