# %% [markdown]
# ## Twitter Streaming App
# This is the code to run a Stream Listener to capture Twitter feeds based on a specific keyword list (could be hashtags)<br>
# <b>Each tweet is analysed for sentiment and emotion in realtime <br>
#    and the tweet+analysis+goe-coordinates are saved on a Cloudant database for further processing/display etc</b>

# %%
import pip
pip.__version__
# !python3 -m pip install --user tweepy
# !python3 -m pip install --user cloudant
# !pip install --upgrade watson-developer-cloud

# %% [markdown]
# The following cell contains code to connect to Twitter
# requires Twitter API keys
#
#
# def <b>connect_to_twitter():</b><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;import tweepy<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;consumerKey = 'xxxxxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;consumerSecret = 'xxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accessToken = 'xxxxxxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;accessTokenSecret = 'xxxxxxxxxxxxxxxxxxxxxx'<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;auth = tweepy.OAuthHandler(consumerKey, consumerSecret)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;auth.set_access_token(accessToken, accessTokenSecret)<br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;return tweepy.API(auth_handler=auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)  <br>

# %%
# The code was removed by Watson Studio for sharing.

# %%
#from twitterconnect import connect_to_twitter
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

# %% [markdown]
# The following cell contains the credentials to access Watson NLU API
#
# #Watson NLU credentials<br>
# credentials_NLU = {<br>
#   'url':'https://gateway.watsonplatform.net/natural-language-understanding/api',<br>
#   'username':'xxxxxxxxxxxxxxxxxxxx',<br>
#   'password':'xxxxxxxxxxxxxxxxxxxxxxxx'<br>
# }<br>

# %%
# The code was removed by Watson Studio for sharing.

# %%
import json
from watson_developer_cloud import NaturalLanguageUnderstandingV1
from watson_developer_cloud.natural_language_understanding_v1 import Features, SentimentOptions, EmotionOptions

NLU_service = NaturalLanguageUnderstandingV1(
    version='2018-03-16',
    ## url is optional, and defaults to the URL below. Use the correct URL for your region.
    # url='https://gateway.watsonplatform.net/natural-language-understanding/api',
    username=credentials_NLU['username'],
    password=credentials_NLU['password'])

# %% [markdown]
# The folowing cell contains Cloudant credentials<br>
# #Cloudant credentials<br>
# credentials_cloudant = {<br>
#   'password':"""xxxxxxxxxxxxxxxxxxxxxx""",<br>
#   'custom_url':'https://xxxxxxxxxxxxxxxxxxxxxxxx-bluemix.cloudant.com',<br>
#   'username':'xxxxxxxxxxxxxxxxxxxxxxxxx-bluemix',<br>
#   'url':'https://undefined'<br>
# }

# %%
# The code was removed by Watson Studio for sharing.

# %%
#connect to Cloudant directly 
from cloudant.client import Cloudant
from cloudant.error import CloudantException
from cloudant.result import Result, ResultByKey

serviceUsername = credentials_cloudant['username']
servicePassword = credentials_cloudant['password']
serviceURL = credentials_cloudant['custom_url']
client = Cloudant(serviceUsername, servicePassword, url=serviceURL)
client.connect()

# %%
#connect via Spark driver

spark = SparkSession\
    .builder\
    .appName("Cloudant Storage for Tweets")\
    .config("cloudant.host",credentials_cloudant['custom_url'].split('@')[1])\
    .config("cloudant.username", credentials_cloudant['username'])\
    .config("cloudant.password",credentials_cloudant['password'])\
    .config("jsonstore.rdd.partitions", 1)\
    .getOrCreate()

#df = spark.read.load("shake_classification", "org.apache.bahir.cloudant")

# %%
#Cloudant database management

def create_tweets_database(db_name):
    database = client.create_database(db_name, throw_on_exists=False)
    if database.exists():
        print("{} database successfully created".format(db_name))
        return database
    else:
        return None
    
def delete_tweets_database(db_name):
    try :
        client.delete_database(db_name)
    except CloudantException:
        print("There was a problem deleting {}.\n".format(db_name))
    else:
        print("{} successfully deleted.\n".format(db_name))

# %%
#Tweets Streaming Classes

def get_center_coordinates(b_box):
    return [sum([b_box[0][x][0] for x in range(4)])/4, sum([b_box[0][x][1] for x in range(4)])/4]


def create_JSON_record(status):
    coords=None
    country=""
    if (status.coordinates != None):
        coords = status.coordinates['coordinates']
    if (status.place != None):
        coords = get_center_coordinates(status.place.bounding_box.coordinates)
        country = status.place.country_code
    try:
        response = NLU_service.analyze(text=status.text, 
            features=Features(sentiment=SentimentOptions(), emotion=EmotionOptions())).get_result()
        tweet_emotion = response['emotion']['document']['emotion']
        tweet_sentiment = response['sentiment']['document']
    except:
        tweet_emotion = {}
        tweet_sentiment = {}        
    json_doc = {
        "dateCreated": status.created_at.isoformat().split('T')[0],
        "timeCreated": status.created_at.isoformat().split('T')[1],
        "country": country,
        "coords": coords,
        "sentiment": tweet_sentiment,
        "emotion": tweet_emotion,
        "text": status.text}
    return json_doc


class Listener(StreamListener):
    def __init__(self, tweets_database):
        super(Listener, self).__init__()
        self.tweets_database = tweets_database
        self.counter=0
        
    def on_status(self, status):
        if (status.place != None) or (status.coordinates != None):
            self.counter +=1
            json_doc = create_JSON_record(status)
            print("#{:d} date/time: {}/{} country: {} coords: {}". format(self.counter,
                                    json_doc["dateCreated"],json_doc["timeCreated"], json_doc["country"], json_doc["coords"]))
            print("sentiment: {} emotion: {}". format(json_doc["sentiment"], json_doc["emotion"]))
 
            print("text: ", json_doc["text"])
            new_record = self.tweets_database.create_document(json_doc)
        return True

    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False
        
        
class TwitterStreamer():  #Class for streaming and processing live tweets.
    def __init__(self, filter_list):
        self.filter_list = filter_list
        pass

    def stream_tweets(self, tweets_database):
        #This handles Twitter authetification and the connection to Twitter Streaming API
        listener = Listener(tweets_database)
        stream = Stream(twapi.auth, listener)
        #This line filter Twitter Streams to capture data by the keywords: 
        stream.filter(track=self.filter_list)

# %% [markdown]
# ## MAIN LOOP

# %%
#Main streaming procedure       
    
hash_tag_list = ['brexit']
tweets_database = create_tweets_database("brexit_tweets")
twapi=connect_to_twitter()        
        
if __name__ == '__main__':
    ts = TwitterStreamer(hash_tag_list)
    try:
        ts.stream_tweets(tweets_database)
    except KeyboardInterrupt:
        print("exited early")
    #client.disconnect()
# Out:
# brexit_tweets database successfully created
# #1 date/time: 2018-10-18/10:58:26 country: GB coords: [-1.449612, 53.3831645]
# sentiment: {'score': 0.784187, 'label': 'positive'} emotion: {'sadness': 0.109548, 'joy': 0.62094, 'anger': 0.144433, 'disgust': 0.054205, 'fear': 0.084297}
# text:  This is important! So long beef trade deal! #brexit #peoplesvote
# #2 date/time: 2018-10-18/10:59:14 country: GB coords: [-3.0033304999999997, 53.632616]
# sentiment: {'score': -0.541009, 'label': 'negative'} emotion: {'sadness': 0.662423, 'joy': 0.054157, 'anger': 0.132683, 'disgust': 0.189046, 'fear': 0.187289}
# text:  @SkyNewsPolitics @SkyNews @Jacob_Rees_Mogg "I think it's a poorly thought-through idea"   Unlike the Brexit referen… https://t.co/0vuAtaTgZl
# #3 date/time: 2018-10-18/10:59:47 country: GB coords: [-0.3289185, 52.5495755]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.571557, 'joy': 0.125085, 'anger': 0.069175, 'disgust': 0.269251, 'fear': 0.195669}
# text:  #Kool_Satsuma &amp; his friends are all very confused 🤷‍♂️ by the #brexit #negotiations and the #politics surrounding t… https://t.co/yOb1FfjOvu
# #4 date/time: 2018-10-18/11:00:04 country: GB coords: [-0.130356, 50.840332]
# sentiment: {} emotion: {}
# text:  Brexit(英国のEU離脱)が近づく今日、自然とイギリス人の友だちとの会話や授業中に教授たちも話題にあげるようになるんだが、
#
# 今日、学科の主任教授が「俺イタリア国籍にすると思う」と突然宣言したのはビビった。
#
# (ちなみに奥さんがイタリア人で、その人も移民学科の教授)
# #5 date/time: 2018-10-18/11:00:05 country: IE coords: [-6.399521, 53.2735025]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.339645, 'joy': 0.057615, 'anger': 0.058207, 'disgust': 0.171263, 'fear': 0.179821}
# text:  Brexit: UK to consider longer transition period - BBC News https://t.co/qYwqE1JFro
# #6 date/time: 2018-10-18/11:00:15 country: GB coords: [0.2515055, 51.142153]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.292366, 'joy': 0.338078, 'anger': 0.205775, 'disgust': 0.081632, 'fear': 0.246064}
# text:  @gaurangmorjaria Very good points but I think now it’s the time to find synergies and unite forces to put Brexit to sleep
# #7 date/time: 2018-10-18/11:00:33 country: GB coords: [-1.0853245, 53.9662065]
# sentiment: {'score': -0.325045, 'label': 'negative'} emotion: {'sadness': 0.201232, 'joy': 0.131425, 'anger': 0.134872, 'disgust': 0.166232, 'fear': 0.163014}
# text:  @tnewtondunn @BBCr4today I will not be affected by Brexit apart from at the edges . I'm not a multi millionaire but… https://t.co/uVzMrpgWqd
# #8 date/time: 2018-10-18/11:00:35 country: NL coords: [4.3063955, 52.076868000000005]
# sentiment: {} emotion: {}
# text:  Ik moet er niet aan denken dat wij in een Nexit belanden. Europese samenwerking maakt ons sterker! Laten we dat met… https://t.co/8N9iDdssrg
# #9 date/time: 2018-10-18/11:00:49 country: IT coords: [12.5451455, 41.898416499999996]
# sentiment: {'score': -0.821399, 'label': 'negative'} emotion: {'sadness': 0.335601, 'joy': 0.08224, 'anger': 0.604028, 'disgust': 0.049031, 'fear': 0.092959}
# text:  Mad cow disease returns in time for Brexit @PeterMannionMP
# #10 date/time: 2018-10-18/11:00:54 country: GB coords: [-2.0080795, 52.699658]
# sentiment: {'score': -0.824233, 'label': 'negative'} emotion: {'sadness': 0.073232, 'joy': 0.013288, 'anger': 0.023275, 'disgust': 0.188902, 'fear': 0.873635}
# text:  @cathgiav1 @MikeH_PR @acgrayling The silence from Labour regarding the real fears around Brexit has been deafening
# #11 date/time: 2018-10-18/11:01:02 country: GB coords: [-0.0350195, 51.5148305]
# sentiment: {'score': -0.576216, 'label': 'negative'} emotion: {'sadness': 0.346157, 'joy': 0.047048, 'anger': 0.033894, 'disgust': 0.751526, 'fear': 0.022813}
# text:  Two rich, white, elderly, Tory supporting males voted for Brexit. Apparently, this is news. #rogerdaltrey #michaelcaine #r4today
# #12 date/time: 2018-10-18/11:01:22 country:  coords: [-0.19755, 51.48661]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.220043, 'joy': 0.246156, 'anger': 0.049414, 'disgust': 0.208577, 'fear': 0.032779}
# text:  @ParisLaDefense @Bellier_Fin Discussing #Brexit &amp; Paris’s La Défense business district now and post brexit with… https://t.co/9i5KGV8JkU
# #13 date/time: 2018-10-18/11:01:26 country: GB coords: [-6.3042765, 55.061058]
# sentiment: {'score': 0.770953, 'label': 'positive'} emotion: {'sadness': 0.020487, 'joy': 0.927734, 'anger': 0.005448, 'disgust': 0.019697, 'fear': 0.014661}
# text:  Proud of NI
# #14 date/time: 2018-10-18/11:01:54 country: GB coords: [-0.130356, 50.840332]
# sentiment: {'score': -0.457893, 'label': 'negative'} emotion: {'sadness': 0.335081, 'joy': 0.05318, 'anger': 0.284878, 'disgust': 0.396208, 'fear': 0.252612}
# text:  It's curious how Tory Brexiters have forgotten the lessons about Non-Tariff Barriers that led Margaret Thatcher to… https://t.co/Ng9ndOUS7q
# #15 date/time: 2018-10-18/11:02:34 country: GB coords: [-0.018734, 51.5992555]
# sentiment: {'score': 0.187856, 'label': 'positive'} emotion: {'sadness': 0.377735, 'joy': 0.417188, 'anger': 0.148249, 'disgust': 0.030459, 'fear': 0.093059}
# text:  "Well done everybody"
#
# OK Misery Hour next
#
# But he'll open somehow with a Brexit dig
#
# #OBINGO
# #16 date/time: 2018-10-18/11:02:55 country: GB coords: [-0.21610800000000002, 51.498387]
# sentiment: {'score': -0.411785, 'label': 'negative'} emotion: {'sadness': 0.637443, 'joy': 0.142284, 'anger': 0.07548, 'disgust': 0.09972, 'fear': 0.188297}
# text:  I wonder what other subject or we could have spent the last two years talking and thinking about if Brexit had neve… https://t.co/B0vWAsFnzP
# #17 date/time: 2018-10-18/11:03:05 country: GB coords: [-0.5488355, 51.316522]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.316344, 'joy': 0.277977, 'anger': 0.048031, 'disgust': 0.092393, 'fear': 0.074735}
# text:  Letter signed by Brexiter “big beasts” shows paucity of ambition - they acknowledge their goal is to continue tradi… https://t.co/izKMdrRXQF
# #18 date/time: 2018-10-18/11:03:39 country: GB coords: [-6.0247025, 54.551736500000004]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.449762, 'joy': 0.009968, 'anger': 0.290546, 'disgust': 0.088941, 'fear': 0.502012}
# text:  @RobDotHutton @SaHreports He implied greed would overcome Brexit problems, and as a forthright Brexiteer, he believ… https://t.co/cR6oK6ueRF
# #19 date/time: 2018-10-18/11:03:54 country: GB coords: [-0.17311500000000002, 51.524835499999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.340338, 'joy': 0.201229, 'anger': 0.199141, 'disgust': 0.201795, 'fear': 0.184368}
# text:  @CapitalOfficial News.. Just wanna correct you on your midday news that it’s NOT an Irish boarder it’s a British Boarder #brexit 🇮🇪
# #20 date/time: 2018-10-18/11:03:56 country: GB coords: [-0.21610800000000002, 51.498387]
# sentiment: {'score': -0.4463, 'label': 'negative'} emotion: {'sadness': 0.637443, 'joy': 0.142284, 'anger': 0.07548, 'disgust': 0.09972, 'fear': 0.188297}
# text:  I wonder what other subject we could have spent the last two years talking and thinking about if Brexit had never b… https://t.co/w5h0WMsr2V
# #21 date/time: 2018-10-18/11:04:55 country: GB coords: [-2.7751314999999996, 54.068005]
# sentiment: {'score': -0.903313, 'label': 'negative'} emotion: {'sadness': 0.248007, 'joy': 0.012793, 'anger': 0.111314, 'disgust': 0.776019, 'fear': 0.126007}
# text:  @NadineDorries Brexit is a mess all of the Tories making. If you force her out I’ll see labour increase my taxes an… https://t.co/W6EPif9uCb
# #22 date/time: 2018-10-18/11:05:07 country: GB coords: [-0.57184, 51.458746500000004]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.35885, 'joy': 0.25106, 'anger': 0.096791, 'disgust': 0.337797, 'fear': 0.114223}
# text:  Our #parliament must have a vote on the most important decision this country has faced since 1939 or there will be… https://t.co/afpKypakMt
# #23 date/time: 2018-10-18/11:05:11 country: GB coords: [-1.8906405, 52.4939665]
# sentiment: {'score': -0.623806, 'label': 'negative'} emotion: {'sadness': 0.150289, 'joy': 0.058763, 'anger': 0.287939, 'disgust': 0.665339, 'fear': 0.102816}
# text:  #Brexit the biggest democratic vote in our history.
# Ken Clarke calls it a silly opinion poll!
# Arrogant has-been.
# #24 date/time: 2018-10-18/11:05:15 country: GB coords: [-5.928412999999999, 54.595869]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.242561, 'joy': 0.138422, 'anger': 0.202261, 'disgust': 0.12349, 'fear': 0.041956}
# text:  @NigelFinlay5 @KenReid_utv But it is necessary for business to continue being competitive in rhe UK market. We need… https://t.co/3hhR5ufGeP
# #25 date/time: 2018-10-18/11:05:48 country: GB coords: [-6.3042765, 55.061058]
# sentiment: {'score': 0.786659, 'label': 'positive'} emotion: {'sadness': 0.222646, 'joy': 0.08693, 'anger': 0.188313, 'disgust': 0.147213, 'fear': 0.119165}
# text:  @Luiseach I think it's a reference to the iceberg we're going to hit post Brexit.
# #26 date/time: 2018-10-18/11:06:10 country: GB coords: [-0.102162, 51.5879015]
# sentiment: {'score': -0.721888, 'label': 'negative'} emotion: {'sadness': 0.221495, 'joy': 0.019608, 'anger': 0.209795, 'disgust': 0.528982, 'fear': 0.419627}
# text:  @allanjenkins21 TOTALLY bloody sick of it. Today Programme is totally pro-Brexit. You wonder why....
# #27 date/time: 2018-10-18/11:06:18 country: GB coords: [-1.3494245, 53.7235335]
# sentiment: {'score': -0.0883945, 'label': 'negative'} emotion: {'sadness': 0.528329, 'joy': 0.014691, 'anger': 0.426105, 'disgust': 0.11965, 'fear': 0.202325}
# text:  @BBCBreaking @bbc5live Apparently BSE 'Mad Cow Disease' has been found on a farm in Aberdeenshire. Don't worry it h… https://t.co/uY5Jdsj3n5
# #28 date/time: 2018-10-18/11:06:20 country: AQ coords: [0.0, -69.468835]
# sentiment: {'score': -0.364751, 'label': 'negative'} emotion: {'sadness': 0.287815, 'joy': 0.019746, 'anger': 0.112907, 'disgust': 0.759683, 'fear': 0.098649}
# text:  @Another_Europe @IanDunt Should say "stop any Brexit Tory or Labour"
# #29 date/time: 2018-10-18/11:06:41 country: GB coords: [-1.449612, 53.3831645]
# sentiment: {'score': 0.619781, 'label': 'positive'} emotion: {'sadness': 0.350041, 'joy': 0.49, 'anger': 0.162949, 'disgust': 0.021688, 'fear': 0.018982}
# text:  My favourite political thing at the moment is all these student,hipsters,remoaners,brexiteers all harping on about… https://t.co/V34BGSnt0Y
# #30 date/time: 2018-10-18/11:06:52 country: GB coords: [-0.442361, 51.537061]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @AwayFromTheKeys @Wittgenstein016 @MrFoxxQFD @champagne_lefty @MattGeeSymonds @sybillerompe @Globan999… https://t.co/WNXBjLPG4W
# #31 date/time: 2018-10-18/11:07:01 country: GB coords: [-0.39004099999999997, 50.8313395]
# sentiment: {'score': -0.305419, 'label': 'negative'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @hsilkchampagne Brexit.
# #32 date/time: 2018-10-18/11:07:28 country: GB coords: [-0.17311500000000002, 51.524835499999995]
# sentiment: {'score': -0.77762, 'label': 'negative'} emotion: {'sadness': 0.094838, 'joy': 0.019213, 'anger': 0.822909, 'disgust': 0.189879, 'fear': 0.041261}
# text:  @vinterspark @LBC @mrjamesob No we wouldn't have
# We remainers were not involved in the implementation of this idiot… https://t.co/pCBUoPi8aV
# #33 date/time: 2018-10-18/11:07:40 country: GB coords: [-0.130356, 50.840332]
# sentiment: {'score': -0.925273, 'label': 'negative'} emotion: {'sadness': 0.342082, 'joy': 0.293426, 'anger': 0.210815, 'disgust': 0.239635, 'fear': 0.09984}
# text:  A reminder, the Sun had to apologise for this completely false story about post-Brexit price cuts. Jacob Rees-Mogg… https://t.co/sAQXh5ynJ5
# #34 date/time: 2018-10-18/11:07:47 country: GB coords: [-2.0877745, 51.8963135]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @MakeVotesMatter @pollytoynbee @PeterTatchell @jreynoldsMP @CompassOffice @JohnCleese @dark_shark @CarolineLucas… https://t.co/wX48gujgdG
# #35 date/time: 2018-10-18/11:08:08 country: GB coords: [-0.0706035, 51.464686]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.462256, 'joy': 0.071435, 'anger': 0.133266, 'disgust': 0.19881, 'fear': 0.235109}
# text:  In todays Brexit news, our government are 'considering an extension to the transision period'. Surely that's for th… https://t.co/CcDlMBp208
# #36 date/time: 2018-10-18/11:08:13 country: IE coords: [-6.2476215, 53.354902499999994]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.357508, 'joy': 0.19206, 'anger': 0.210506, 'disgust': 0.215643, 'fear': 0.069772}
# text:  There’s only one political power that ever divided Ireland, and I’ll give you a clue, it wasn’t the EU #brexit
# #37 date/time: 2018-10-18/11:08:17 country: BE coords: [3.714562, 51.083746000000005]
# sentiment: {} emotion: {}
# text:  Brexit update #VIB #KPMG @ Gent, Belgium https://t.co/2iAQHC02zA
# #38 date/time: 2018-10-18/11:08:28 country: GB coords: [-1.6453615, 54.992055500000006]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.062073, 'joy': 0.464904, 'anger': 0.012287, 'disgust': 0.168184, 'fear': 0.07368}
# text:  Howling at this reply 👏🏻
# #39 date/time: 2018-10-18/11:08:29 country: GB coords: [-2.23348, 53.4569525]
# sentiment: {} emotion: {}
# text:  Michael Caine!
# #40 date/time: 2018-10-18/11:09:10 country: GB coords: [-2.3255035, 53.6948935]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.424129, 'joy': 0.057736, 'anger': 0.101375, 'disgust': 0.234645, 'fear': 0.165872}
# text:  Aye, so what is the point of Brexit? 🤷‍♀️
# #41 date/time: 2018-10-18/11:09:12 country: DE coords: [9.372679499999998, 53.679886499999995]
# sentiment: {'score': -0.737174, 'label': 'negative'} emotion: {'sadness': 0.16961, 'joy': 0.010282, 'anger': 0.612201, 'disgust': 0.261876, 'fear': 0.335535}
# text:  “You’re only supposed to knock on the bloody door!”
# #42 date/time: 2018-10-18/11:09:13 country: GB coords: [-4.200441, 57.739454]
# sentiment: {'score': -0.733718, 'label': 'negative'} emotion: {'sadness': 0.148667, 'joy': 0.266763, 'anger': 0.07818, 'disgust': 0.154174, 'fear': 0.069564}
# text:  So @OwenPaterson MP says to May: "Just get on with it." As ever the pro-Brexiteers have no real answers for #Brexit… https://t.co/I7ZR0MAkQX
# #43 date/time: 2018-10-18/11:09:39 country: GB coords: [-0.21089449999999998, 51.6118845]
# sentiment: {'score': -0.120523, 'label': 'negative'} emotion: {'sadness': 0.08166, 'joy': 0.71394, 'anger': 0.128343, 'disgust': 0.027744, 'fear': 0.078592}
# text:  Brexit - What a mess!!
#
# Either way you voted, NOBODY can be happy with what is happening and how Mrs. May is handl… https://t.co/wHNRyUUdYu
# #44 date/time: 2018-10-18/11:09:53 country: GB coords: [0.317777, 51.4864855]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.331728, 'joy': 0.540234, 'anger': 0.042918, 'disgust': 0.045225, 'fear': 0.046637}
# text:  I love both Roger Daltrey and Michael Caine, but the idea I'd take a blind bit of notice what gereatric multi-milli… https://t.co/iBrROwbjFp
# #45 date/time: 2018-10-18/11:10:05 country: ES coords: [-3.7035075, 40.4777945]
# sentiment: {'score': 0.266532, 'label': 'positive'} emotion: {'sadness': 0.032805, 'joy': 0.914401, 'anger': 0.013243, 'disgust': 0.024123, 'fear': 0.014526}
# text:  Quite funny actually. On point! I think the mocking is deserved 😄 #brexit #singlemarket
# #46 date/time: 2018-10-18/11:10:15 country: NL coords: [5.466834499999999, 51.38584399999999]
# sentiment: {} emotion: {}
# text:  Jetten, het D66 "regentje" in de dop, ter herinnering voor deze Papagaai; Het NL'se volk:
# - Wil geen (Eu) grondwet… https://t.co/2ElwI0cYbl
# #47 date/time: 2018-10-18/11:10:31 country: GB coords: [-2.3609355, 51.695001000000005]
# sentiment: {'score': -0.81831, 'label': 'negative'} emotion: {'sadness': 0.435813, 'joy': 0.016678, 'anger': 0.502892, 'disgust': 0.082424, 'fear': 0.244247}
# text:  @christopherhope She's been a zombie PM since GE17  but she's still the only one stupid enough to want to lead that… https://t.co/1y8naP8i4A
# #48 date/time: 2018-10-18/11:10:32 country: IE coords: [-6.174398500000001, 53.257283]
# sentiment: {'score': 0.796637, 'label': 'positive'} emotion: {'sadness': 0.322354, 'joy': 0.198066, 'anger': 0.132368, 'disgust': 0.103706, 'fear': 0.149082}
# text:  @Liampcahill For Brexit yes it would..... but for a lot of people in the North and Westminster is would be realistic.
# #49 date/time: 2018-10-18/11:10:44 country: GB coords: [-0.7576449999999999, 51.249951]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.08295, 'joy': 0.453087, 'anger': 0.013637, 'disgust': 0.361784, 'fear': 0.103047}
# text:  And thats just for the tory cabinet 😸
# #50 date/time: 2018-10-18/11:10:46 country: GB coords: [-0.09291050000000001, 51.5144805]
# sentiment: {'score': -0.709894, 'label': 'negative'} emotion: {'sadness': 0.125277, 'joy': 0.412767, 'anger': 0.149469, 'disgust': 0.179198, 'fear': 0.195909}
# text:  Take back control of our borders!!1!1!
#
# No, not that border
# #51 date/time: 2018-10-18/11:10:53 country: GB coords: [-2.5208115, 53.25884]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.08665, 'joy': 0.574371, 'anger': 0.071726, 'disgust': 0.051113, 'fear': 0.082903}
# text:  @jordandias Sounds more like an unhappy Blairite content to follow the narrative of the right wing press. As for Co… https://t.co/IrgGLhzBN7
# #52 date/time: 2018-10-18/11:11:08 country: IT coords: [11.752976499999999, 45.627493]
# sentiment: {'score': -0.375992, 'label': 'negative'} emotion: {'sadness': 0.327008, 'joy': 0.491474, 'anger': 0.20578, 'disgust': 0.056683, 'fear': 0.015264}
# text:  Young people won’t forgive those who deny us a vote on this botched Brexit | Lara Spirit https://t.co/vvOMZTH5gX
# #53 date/time: 2018-10-18/11:11:31 country: GB coords: [-0.189289, 51.4108755]
# sentiment: {'score': 0.776005, 'label': 'positive'} emotion: {'sadness': 0.101997, 'joy': 0.09546, 'anger': 0.221457, 'disgust': 0.119648, 'fear': 0.511849}
# text:  I am really concerned about Brexit. My English boss says me: Javier, you don't worry you are safe in Wimbledon the… https://t.co/wcEhcqtHYv
# #54 date/time: 2018-10-18/11:12:32 country: GB coords: [-0.09263300000000001, 51.358931]
# sentiment: {'score': -0.781109, 'label': 'negative'} emotion: {'sadness': 0.47742, 'joy': 0.041513, 'anger': 0.371265, 'disgust': 0.150631, 'fear': 0.16452}
# text:  @EmmanuelMacron are you being “desperately SILLY’
# #55 date/time: 2018-10-18/11:12:34 country: GB coords: [-4.2417514999999995, 55.85830249999999]
# sentiment: {'score': -0.67923, 'label': 'negative'} emotion: {'sadness': 0.11593, 'joy': 0.425402, 'anger': 0.024078, 'disgust': 0.055743, 'fear': 0.182093}
# text:  Brexiters have no sense of history!
# #56 date/time: 2018-10-18/11:12:43 country: GB coords: [0.6115010000000001, 51.644195499999995]
# sentiment: {'score': -0.4321, 'label': 'negative'} emotion: {'sadness': 0.329394, 'joy': 0.07056, 'anger': 0.29283, 'disgust': 0.147028, 'fear': 0.181665}
# text:  A deal or no deal vote? That’s “farcical” from “Raab C. Brexit”, says McDonnell https://t.co/VkJkFDDgMA https://t.co/yIx8clqS07
# #57 date/time: 2018-10-18/11:12:45 country: AU coords: [145.0531355, -37.9725665]
# sentiment: {'score': -0.839163, 'label': 'negative'} emotion: {'sadness': 0.548238, 'joy': 0.054036, 'anger': 0.257486, 'disgust': 0.316905, 'fear': 0.072789}
# text:  Can you please try and keep Theresa May and #Brexit of my Australian TV screens. Its the most boring world story in… https://t.co/8p6qMbzeGN
# #58 date/time: 2018-10-18/11:12:57 country: GB coords: [-0.442361, 51.537061]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @MattGeeSymonds @AwayFromTheKeys @Wittgenstein016 @MrFoxxQFD @champagne_lefty @sybillerompe @Globan999… https://t.co/i4IE8ST5Ds
# #59 date/time: 2018-10-18/11:12:58 country: GB coords: [-0.17311500000000002, 51.524835499999995]
# sentiment: {'score': 0.475127, 'label': 'positive'} emotion: {'sadness': 0.380948, 'joy': 0.250474, 'anger': 0.092769, 'disgust': 0.165235, 'fear': 0.11651}
# text:  Clinging to Brexit like Medusa raft. Knowing you are on the Titanic but onwards and backwards 1973 closer by the mo… https://t.co/pTk4ixcYCE
# #60 date/time: 2018-10-18/11:13:07 country: GB coords: [-2.0877745, 51.8963135]
# sentiment: {'score': -0.77683, 'label': 'negative'} emotion: {'sadness': 0.642331, 'joy': 0.048148, 'anger': 0.148827, 'disgust': 0.195931, 'fear': 0.184746}
# text:  @guardian Any discussion of UK austerity that fails to mention EU-Troika mandated spending limits is simply risible… https://t.co/eSuUkBJaxD
# #61 date/time: 2018-10-18/11:13:20 country: GB coords: [-1.590952, 53.739596]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.052223, 'joy': 0.094422, 'anger': 0.041355, 'disgust': 0.178127, 'fear': 0.128931}
# text:  @DogManStar @MimiRossiJ @brightsider123 @Keir_Starmer The polls show Brexit is more popular than May. That is signi… https://t.co/SWKSME7h6s
# #62 date/time: 2018-10-18/11:13:27 country: IE coords: [-6.2476215, 53.354902499999994]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.223481, 'joy': 0.107148, 'anger': 0.383904, 'disgust': 0.290415, 'fear': 0.159771}
# text:  On #CNNTalk @IainDale is talking through his backside about #Ireland. Please get @MaireadMcGMEP on to slap some… https://t.co/wSAoUnSf45
# #63 date/time: 2018-10-18/11:14:03 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': 0.527285, 'label': 'positive'} emotion: {'sadness': 0.032259, 'joy': 0.541931, 'anger': 0.018328, 'disgust': 0.049489, 'fear': 0.025799}
# text:  BREXIT - Paris La Défense and partners present market trends, opportunities and iconic projects of the largest euro… https://t.co/T1gBB48uDW
# #64 date/time: 2018-10-18/11:14:11 country: GB coords: [-0.055730999999999996, 51.718321]
# sentiment: {'score': -0.383498, 'label': 'negative'} emotion: {'sadness': 0.38661, 'joy': 0.358555, 'anger': 0.105142, 'disgust': 0.069252, 'fear': 0.111661}
# text:  Looking very dapper today @BBCNormanS in blue, making talk of Brexit almost bearable.
# #65 date/time: 2018-10-18/11:14:53 country: GB coords: [-2.3267745, 53.4001995]
# sentiment: {'score': -0.570629, 'label': 'negative'} emotion: {'sadness': 0.578916, 'joy': 0.039707, 'anger': 0.021732, 'disgust': 0.037244, 'fear': 0.259695}
# text:  The main irony here is that if Brexiteer MPs manage to unseat her, it will probably bring about... a longer transit… https://t.co/AuMqiQ6tjn
# #66 date/time: 2018-10-18/11:14:57 country: GB coords: [-2.5853900000000003, 51.457876999999996]
# sentiment: {'score': -0.687206, 'label': 'negative'} emotion: {'sadness': 0.201117, 'joy': 0.199288, 'anger': 0.181019, 'disgust': 0.122341, 'fear': 0.087882}
# text:  So brexit allows you to be:
# "Poor and the master of your own destiny*"
# Which would be better than remaining in the… https://t.co/PNP1lZTokh
# #67 date/time: 2018-10-18/11:15:06 country: GB coords: [-0.130356, 50.840332]
# sentiment: {'score': -0.354366, 'label': 'negative'} emotion: {'sadness': 0.598176, 'joy': 0.025229, 'anger': 0.210919, 'disgust': 0.141062, 'fear': 0.164286}
# text:  It's up to 72k. Let's push this petition over 100k!
# Petitition: If there is no agreement to leave the EU then brexi… https://t.co/wAarJX0YaG
# #68 date/time: 2018-10-18/11:15:28 country: GB coords: [-1.76682, 53.8159335]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.179654, 'joy': 0.622242, 'anger': 0.048817, 'disgust': 0.022316, 'fear': 0.023818}
# text:  Business booming at Skipton-based Whitakers Chocolates despite Brexit uncertainty https://t.co/749eBJ8Lmi https://t.co/dCaNnxXqL3
# #69 date/time: 2018-10-18/11:15:35 country: GB coords: [-0.130356, 50.840332]
# sentiment: {'score': -0.519671, 'label': 'negative'} emotion: {'sadness': 0.332455, 'joy': 0.014283, 'anger': 0.138496, 'disgust': 0.704218, 'fear': 0.136207}
# text:  Sickening to witness really.
# JRM suddenly cares about Universal Credit
# Every Brexiter apparently cares deeply about… https://t.co/txK4XqfDFI
# #70 date/time: 2018-10-18/11:15:37 country: MC coords: [7.424292, 43.738347000000005]
# sentiment: {'score': 0.913054, 'label': 'positive'} emotion: {'sadness': 0.111436, 'joy': 0.613411, 'anger': 0.053253, 'disgust': 0.039146, 'fear': 0.04977}
# text:  Well, that's one way of looking at it.
# #71 date/time: 2018-10-18/11:15:40 country: GB coords: [-1.186364, 53.1486735]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.314732, 'joy': 0.162153, 'anger': 0.245388, 'disgust': 0.230957, 'fear': 0.083754}
# text:  It's @richardpbacon asking people abour brexit in Mansfield https://t.co/Zuh67iSPjz
# #72 date/time: 2018-10-18/11:16:12 country: GB coords: [-0.17311500000000002, 51.524835499999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.181677, 'joy': 0.195606, 'anger': 0.108645, 'disgust': 0.114712, 'fear': 0.108196}
# text:  So how is Brexit today Theresa? #Brexit #Brexitcast https://t.co/D8379mVLhX
# #73 date/time: 2018-10-18/11:16:20 country: GB coords: [0.328125, 52.276917]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.431114, 'joy': 0.018127, 'anger': 0.363535, 'disgust': 0.086203, 'fear': 0.416666}
# text:  Brexit a ‘colossal misjudgment’ that could break up UK, Major warns https://t.co/gcD8yCkAfh
# #74 date/time: 2018-10-18/11:16:34 country: BE coords: [4.375364, 50.820670500000006]
# sentiment: {'score': -0.588697, 'label': 'negative'} emotion: {'sadness': 0.654686, 'joy': 0.042215, 'anger': 0.287396, 'disgust': 0.148715, 'fear': 0.105734}
# text:  John Major rips into #BorisJohnson and fellow Brexiteers, saying they'll never be forgiven https://t.co/xSWk8B02GV #Brexit
# #75 date/time: 2018-10-18/11:16:55 country: GB coords: [-0.09291050000000001, 51.5144805]
# sentiment: {'score': -0.433151, 'label': 'negative'} emotion: {'sadness': 0.322361, 'joy': 0.162571, 'anger': 0.067689, 'disgust': 0.171838, 'fear': 0.416525}
# text:  Int convo with @valentinapop &amp; @ChristianFraser re @theresa_may &amp; the eu 27. Problem is that as May has shown her e… https://t.co/J1n98BWnbx
# #76 date/time: 2018-10-18/11:17:10 country: GB coords: [-0.26091549999999997, 51.344775]
# sentiment: {'score': -0.790588, 'label': 'negative'} emotion: {'sadness': 0.423771, 'joy': 0.27512, 'anger': 0.085034, 'disgust': 0.060067, 'fear': 0.086773}
# text:  So hard #Brexit means global isolation @theresa_may so if it goes ahead complete meltdown is Lilly to follow, this… https://t.co/UmOGFR1jOQ
# #77 date/time: 2018-10-18/11:17:12 country: GB coords: [-2.5853900000000003, 51.457876999999996]
# sentiment: {'score': 0.967826, 'label': 'positive'} emotion: {'sadness': 0.027908, 'joy': 0.477263, 'anger': 0.212513, 'disgust': 0.064193, 'fear': 0.091978}
# text:  @uk_domain_names Oh I seeeee. Fair enough, thanks for educating me. Personally, I think that although we may have s… https://t.co/J0wOOl8Pzi
# #78 date/time: 2018-10-18/11:17:32 country: GB coords: [-2.4695394999999998, 56.719006]
# sentiment: {'score': -0.582249, 'label': 'negative'} emotion: {'sadness': 0.111891, 'joy': 0.163718, 'anger': 0.035759, 'disgust': 0.03992, 'fear': 0.530526}
# text:  "To overcome Brexit impasse, May open to extending transition" - https://t.co/H6tQCgm8aS
# #79 date/time: 2018-10-18/11:17:52 country: GB coords: [-2.4837505, 53.728524]
# sentiment: {'score': -0.814841, 'label': 'negative'} emotion: {'sadness': 0.888623, 'joy': 0.011772, 'anger': 0.025694, 'disgust': 0.080945, 'fear': 0.078972}
# text:  Sadly - if she extends, then you’re right. :(
# #80 date/time: 2018-10-18/11:17:57 country: GB coords: [0.049338, 50.7946395]
# sentiment: {'score': 0.882011, 'label': 'positive'} emotion: {'sadness': 0.060946, 'joy': 0.683921, 'anger': 0.064943, 'disgust': 0.08723, 'fear': 0.102458}
# text:  It’s actually quite amusing now
# #81 date/time: 2018-10-18/11:18:37 country: GB coords: [-0.26091549999999997, 51.344775]
# sentiment: {} emotion: {}
# text:  #StopBrexitSaveBritain
# #82 date/time: 2018-10-18/11:18:47 country: GB coords: [-1.4407025, 54.977920499999996]
# sentiment: {'score': -0.618403, 'label': 'negative'} emotion: {'sadness': 0.479928, 'joy': 0.056355, 'anger': 0.22425, 'disgust': 0.4577, 'fear': 0.106901}
# text:  You shoutand shout loudly about Will of People and it’s all about taking back control. Now you want to ignore Will… https://t.co/Ea5kZFaZtb
# #83 date/time: 2018-10-18/11:19:01 country: DE coords: [13.4246065, 52.506701]
# sentiment: {'score': -0.0217132, 'label': 'negative'} emotion: {'sadness': 0.061678, 'joy': 0.644433, 'anger': 0.035177, 'disgust': 0.036734, 'fear': 0.019342}
# text:  @darrengrimes_ @peoplesvote_uk No, it's not the fault of Brexit. But it's a perfect example of why the backstop is… https://t.co/6gmOXNgeEL
# #84 date/time: 2018-10-18/11:19:01 country: GB coords: [-3.452863, 56.06718]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @georgegalloway @Phil_O_Keefe @yona1959 @JackieBhird @PoliticsScot @George_GOWYC @camerob2049 @moo_ted… https://t.co/vauXMYcBvx
# #85 date/time: 2018-10-18/11:19:05 country: GB coords: [-3.1798, 51.497001499999996]
# sentiment: {'score': -0.729639, 'label': 'negative'} emotion: {'sadness': 0.507137, 'joy': 0.03163, 'anger': 0.373395, 'disgust': 0.177144, 'fear': 0.202611}
# text:  The problem when you are trying to explain facts on air to people that only responed with emotion… https://t.co/p69mDqpvQJ
# #86 date/time: 2018-10-18/11:19:38 country: IL coords: [34.9684285, 31.342253000000003]
# sentiment: {} emotion: {}
# text:  #פתיחהמהירה #ארהב מה צריך לדעת:
# תשואות אוצר עולות מניות יורדות על רקע הפרוטוקול
# השווקים מעורבים
# אין עסקת Brexit
# אי… https://t.co/XTi0Uab5DN
# #87 date/time: 2018-10-18/11:19:48 country: NL coords: [4.508210999999999, 52.2737025]
# sentiment: {'score': -0.349018, 'label': 'negative'} emotion: {'sadness': 0.571944, 'joy': 0.028844, 'anger': 0.067801, 'disgust': 0.241108, 'fear': 0.364462}
# text:  Conversation drifted to Brexit. Saw the poor fella’s enthusiasm and light drain from his eyes. Just when I had something to talk about...
# #88 date/time: 2018-10-18/11:19:49 country: GB coords: [-0.17311500000000002, 51.524835499999995]
# sentiment: {'score': -0.919188, 'label': 'negative'} emotion: {'sadness': 0.10534, 'joy': 0.186591, 'anger': 0.586324, 'disgust': 0.174596, 'fear': 0.157142}
# text:  Think #BBCapprentice tweeps’ patience for watching totally incompetent twats run around aimlessly might be exhauste… https://t.co/TNx0xSADau
# #89 date/time: 2018-10-18/11:20:15 country: GB coords: [-2.3862205, 57.2856965]
# sentiment: {'score': 0.763686, 'label': 'positive'} emotion: {'sadness': 0.09129, 'joy': 0.363155, 'anger': 0.024514, 'disgust': 0.150652, 'fear': 0.050722}
# text:  It's a English Brexit and that will benefit the @snp.
# #90 date/time: 2018-10-18/11:20:16 country: GB coords: [-1.930983, 52.2976445]
# sentiment: {'score': 0.120663, 'label': 'positive'} emotion: {'sadness': 0.353521, 'joy': 0.188173, 'anger': 0.089376, 'disgust': 0.036726, 'fear': 0.10378}
# text:  It hasn’t been. There now isn’t enough time to change that. Extending the time available will cause even more damag… https://t.co/UjqHWkjibT
# #91 date/time: 2018-10-18/11:20:16 country: GB coords: [-0.18919, 51.5037865]
# sentiment: {'score': 0.830257, 'label': 'positive'} emotion: {'sadness': 0.074899, 'joy': 0.297736, 'anger': 0.195916, 'disgust': 0.083682, 'fear': 0.0321}
# text:  Derek Zoolander gave us ‘Blue Steel’, now I give you ‘Thinking about Brexit’ #modelposes #Brexithumour @RedHourBen https://t.co/CN4pdG1Nuu
# #92 date/time: 2018-10-18/11:20:20 country: PA coords: [-80.0954175, 8.421673]
# sentiment: {} emotion: {}
# text:  #Mundo May admite que estudian extender la transición del brexit 'unos meses' https://t.co/irn8zFBFWq #NoticiasTVN https://t.co/QFChQlJr99
# #93 date/time: 2018-10-18/11:20:38 country: KH coords: [104.981971, 12.298382]
# sentiment: {'score': -0.409579, 'label': 'negative'} emotion: {'sadness': 0.171519, 'joy': 0.318457, 'anger': 0.133154, 'disgust': 0.076907, 'fear': 0.141108}
# text:  I'd rather have Boaty McBoatface than Brexit any day. If only this could be taken as a legal precedent.
# #94 date/time: 2018-10-18/11:20:51 country: GB coords: [-0.130356, 50.840332]
# sentiment: {'score': -0.433985, 'label': 'negative'} emotion: {'sadness': 0.235911, 'joy': 0.030066, 'anger': 0.299588, 'disgust': 0.356482, 'fear': 0.386561}
# text:  Remainer attacked by Brexit thugs on Brighton Pier.
# https://t.co/TKnQ4OYdG1
# #Brexit is backed by violence and inti… https://t.co/rzVK1LcOjf
# #95 date/time: 2018-10-18/11:20:53 country: GB coords: [-4.2417514999999995, 55.85830249999999]
# sentiment: {'score': 0.933938, 'label': 'positive'} emotion: {'sadness': 0.049644, 'joy': 0.591909, 'anger': 0.185273, 'disgust': 0.072609, 'fear': 0.188007}
# text:  @SpiderSorcerer @JenApparently @InflatableDalek Well to be fair other people aren’t to be trusted.  See also:  Boat… https://t.co/CtIikq8lUL
# #96 date/time: 2018-10-18/11:20:54 country: MV coords: [73.2263065, 3.201397]
# sentiment: {'score': 0.944547, 'label': 'positive'} emotion: {'sadness': 0.149526, 'joy': 0.514115, 'anger': 0.093129, 'disgust': 0.163988, 'fear': 0.186018}
# text:  How about RT with a comment if you think @Nigel_Farage is a muppet headed fascist charlatan with delusions of grand… https://t.co/DvZDeRni2x
# #97 date/time: 2018-10-18/11:21:05 country: GB coords: [-1.13067, 52.6262635]
# sentiment: {'score': -0.594288, 'label': 'negative'} emotion: {'sadness': 0.113614, 'joy': 0.570896, 'anger': 0.035032, 'disgust': 0.008851, 'fear': 0.095897}
# text:  @talkRADIO @JuliaHB1 @BillCashMP If there is a new pm #brexit won't happen
# #98 date/time: 2018-10-18/11:21:17 country: GB coords: [-4.2417514999999995, 55.85830249999999]
# sentiment: {'score': -0.59033, 'label': 'negative'} emotion: {'sadness': 0.500175, 'joy': 0.01661, 'anger': 0.252886, 'disgust': 0.18878, 'fear': 0.337858}
# text:  @ArgyleLoz @BBCr4today Have the clowns on @BBCr4today mentioned the illegality and lies of the leave brexit campaign recently? Thought not!
# #99 date/time: 2018-10-18/11:21:28 country: GB coords: [-1.5186514999999998, 52.411913]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.365295, 'joy': 0.07357, 'anger': 0.11919, 'disgust': 0.057553, 'fear': 0.07657}
# text:  @Hellyer_Steve No mate, BREXIT was not about trade, we don't need a deal, the EU does. It was about sovereignty. Th… https://t.co/NSp4lY7tPT
# #100 date/time: 2018-10-18/11:22:04 country: CA coords: [-125.97237799999999, 55.479046499999995]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.330372, 'joy': 0.271546, 'anger': 0.124659, 'disgust': 0.029226, 'fear': 0.266036}
# text:  @jannylis1 @frankotron @karenbway_karen @Doozy_45 Unlike EU, UK will be working through trade deals rapidly. https://t.co/C0dwF60NLu
# #101 date/time: 2018-10-18/11:22:46 country: PT coords: [-9.159995, 38.743614]
# sentiment: {'score': 0.815877, 'label': 'positive'} emotion: {'sadness': 0.230929, 'joy': 0.178056, 'anger': 0.244229, 'disgust': 0.246923, 'fear': 0.149589}
# text:  @Independent @IndyArts this middle of the ranks actor has made plenty of money ergo Brexit
# #102 date/time: 2018-10-18/11:23:20 country: GB coords: [-0.2527539999999999, 51.3854455]
# sentiment: {'score': -0.86108, 'label': 'negative'} emotion: {'sadness': 0.372342, 'joy': 0.082604, 'anger': 0.259468, 'disgust': 0.226862, 'fear': 0.343937}
# text:  @DVATW And then kick the EU leaving can so far down the road that when the next economic downturn comes, as they do… https://t.co/vN4NOBU1Br
# #103 date/time: 2018-10-18/11:23:25 country: GB coords: [-0.57184, 51.458746500000004]
# sentiment: {'score': -0.711526, 'label': 'negative'} emotion: {'sadness': 0.045024, 'joy': 0.151667, 'anger': 0.299304, 'disgust': 0.493139, 'fear': 0.17083}
# text:  2 ladies who unfortunately do not have #EmotionalIntelligence towards the human side of #Brexit intransigent and si… https://t.co/dpXoiGU2zb
# #104 date/time: 2018-10-18/11:23:26 country: GB coords: [-2.23348, 53.4569525]
# sentiment: {'score': -0.329859, 'label': 'negative'} emotion: {'sadness': 0.46481, 'joy': 0.406509, 'anger': 0.024383, 'disgust': 0.02315, 'fear': 0.046021}
# text:  Yes but not a lot of people know that
# #105 date/time: 2018-10-18/11:23:36 country: GB coords: [-2.915427, 53.4198785]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.399332, 'joy': 0.064703, 'anger': 0.37554, 'disgust': 0.375733, 'fear': 0.130272}
# text:  For goodness sake how hard would it be for some UK politicians from all parties to put the country first. Stand tog… https://t.co/BhpdS0Ojqz
# #106 date/time: 2018-10-18/11:23:51 country: NL coords: [4.7525085, 51.7688035]
# sentiment: {} emotion: {}
# text:  @mennodebruyne De situatie waarin een krappe meerderheid (van de opgekomen kiezers) een erg grote minderheid in het… https://t.co/uz4nyZWg5d
# #107 date/time: 2018-10-18/11:24:00 country: GB coords: [-4.200441, 57.739454]
# sentiment: {'score': -0.821585, 'label': 'negative'} emotion: {'sadness': 0.180673, 'joy': 0.026864, 'anger': 0.788746, 'disgust': 0.077445, 'fear': 0.121322}
# text:  Aye it was a rabid remainer bit the coo on its arse. The beast will have to be killed along with the barking mad re… https://t.co/dzMmjAWrIo
# #108 date/time: 2018-10-18/11:24:18 country: GB coords: [0.565823, 50.8717925]
# sentiment: {'score': -0.33349, 'label': 'negative'} emotion: {'sadness': 0.400432, 'joy': 0.192872, 'anger': 0.146314, 'disgust': 0.200268, 'fear': 0.12788}
# text:  @Nigel_Farage @theresa_may The Brexit transition period to be extended until all Leave voters have died🤣🤣🤣🤣🤣
# #109 date/time: 2018-10-18/11:24:34 country: GB coords: [-0.1091815, 51.5469265]
# sentiment: {'score': -0.498033, 'label': 'negative'} emotion: {'sadness': 0.293782, 'joy': 0.158749, 'anger': 0.346609, 'disgust': 0.107328, 'fear': 0.235784}
# text:  @sbrennan671 Err mobilise to get your brain into gear.  .THEY ARE NOT IN GOV. So can fight guerilla warfare but tha… https://t.co/DDepbLORCG
# #110 date/time: 2018-10-18/11:24:36 country: GB coords: [-2.0877745, 51.8963135]
# sentiment: {'score': -0.911688, 'label': 'negative'} emotion: {'sadness': 0.696611, 'joy': 0.015441, 'anger': 0.298481, 'disgust': 0.176455, 'fear': 0.069224}
# text:  @OwenJones84 @chakrabortty @davidmcw Guardian 'Stop Brexit by ignoring EU' propaganda purdah continues:
#
# Discussin… https://t.co/cCqF03egCK
# #111 date/time: 2018-10-18/11:24:47 country: NG coords: [7.424094, 9.073664]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.049822, 'joy': 0.311292, 'anger': 0.113427, 'disgust': 0.038396, 'fear': 0.018254}
# text:  FTSE 100 vs FTSE 250: Brexit Outcome to Determine FTSE Outperformer - https://t.co/vKLMNA16yU
# #112 date/time: 2018-10-18/11:24:54 country: GB coords: [-2.4695394999999998, 56.719006]
# sentiment: {'score': -0.758538, 'label': 'negative'} emotion: {'sadness': 0.419933, 'joy': 0.046916, 'anger': 0.237727, 'disgust': 0.106929, 'fear': 0.141747}
# text:  EU shelves plans for Brexit divorce deal summit citing lack of progress
# https://t.co/sQlG2lGzne
# #113 date/time: 2018-10-18/11:25:00 country: GB coords: [0.5115780000000001, 52.2204505]
# sentiment: {'score': -0.58553, 'label': 'negative'} emotion: {'sadness': 0.065087, 'joy': 0.073844, 'anger': 0.062093, 'disgust': 0.050193, 'fear': 0.056768}
# text:  @AngryBritain Odd jerky movements . . . Strange facial expressions . . . . And keeps repeating Brexit means Brexit… https://t.co/eGNItwsvUu
# #114 date/time: 2018-10-18/11:25:08 country: GB coords: [-4.200441, 57.739454]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.284544, 'joy': 0.314024, 'anger': 0.073587, 'disgust': 0.065636, 'fear': 0.105552}
# text:  @BillyMcD1 brexit/ back 2 the days of yore. https://t.co/SHCQqNwUO6
# #115 date/time: 2018-10-18/11:25:24 country: GB coords: [-4.2417514999999995, 55.85830249999999]
# sentiment: {'score': 0.125996, 'label': 'positive'} emotion: {'sadness': 0.025951, 'joy': 0.365376, 'anger': 0.049602, 'disgust': 0.137957, 'fear': 0.054782}
# text:  Only just learnt? This is an age old method. Good to see MPs with their finger on the pulse 🙄
# #116 date/time: 2018-10-18/11:25:39 country: GB coords: [-1.0669855000000001, 50.818864500000004]
# sentiment: {'score': 0.0449817, 'label': 'positive'} emotion: {'sadness': 0.45741, 'joy': 0.116136, 'anger': 0.138026, 'disgust': 0.225822, 'fear': 0.107298}
# text:  Non-stop virtue signalling &amp; continual promises of extra investment. Unawareness of Brexit or complete dishonesty?
# #117 date/time: 2018-10-18/11:25:51 country: GB coords: [0.5810675, 51.7283335]
# sentiment: {'score': 0.531576, 'label': 'positive'} emotion: {'sadness': 0.232055, 'joy': 0.286733, 'anger': 0.09829, 'disgust': 0.108094, 'fear': 0.081942}
# text:  @mynameisAndyJ Just in time for Brexit
# #118 date/time: 2018-10-18/11:26:15 country: GB coords: [-0.09263300000000001, 51.358931]
# sentiment: {'score': -0.340791, 'label': 'negative'} emotion: {'sadness': 0.436037, 'joy': 0.164112, 'anger': 0.153797, 'disgust': 0.02182, 'fear': 0.381421}
# text:  You are really causing a major health problem if @theresa_may does not “go” in 2018
# #119 date/time: 2018-10-18/11:26:16 country: GB coords: [-2.8516565, 53.415257]
# sentiment: {'score': 0.0548348, 'label': 'positive'} emotion: {'sadness': 0.188495, 'joy': 0.127672, 'anger': 0.244853, 'disgust': 0.132104, 'fear': 0.079962}
# text:  Let's be clear! @Conservatives call a referendum on EU membership. @David_Cameron didn't get result he expected and… https://t.co/KVZgkCstjm
# #120 date/time: 2018-10-18/11:26:23 country: GB coords: [-4.200441, 57.739454]
# sentiment: {'score': -0.765636, 'label': 'negative'} emotion: {'sadness': 0.704847, 'joy': 0.034744, 'anger': 0.203128, 'disgust': 0.092916, 'fear': 0.229394}
# text:  The real problem with Brexit is that everyone has their own idea of what it will mean and we’re all going to be disappointed.
# #121 date/time: 2018-10-18/11:26:28 country: GB coords: [-0.09291050000000001, 51.5144805]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.137362, 'joy': 0.557058, 'anger': 0.08685, 'disgust': 0.007336, 'fear': 0.200288}
# text:  In conjunction with our International Trade Summit, today we release new research with @dhlexpressuk on the need to… https://t.co/o6UjOeepqr
# #122 date/time: 2018-10-18/11:26:32 country: GB coords: [-4.2417514999999995, 55.85830249999999]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.180723, 'joy': 0.208234, 'anger': 0.131112, 'disgust': 0.141551, 'fear': 0.233583}
# text:  Oh for goodness sake 🙄
# #123 date/time: 2018-10-18/11:26:32 country: VN coords: [105.3469055, 20.708857000000002]
# sentiment: {'score': -0.834438, 'label': 'negative'} emotion: {'sadness': 0.06124, 'joy': 0.706497, 'anger': 0.044243, 'disgust': 0.027574, 'fear': 0.090071}
# text:  @BRRSC @2010LeeHurst Brexit will be very damaging to anyone engaged in collaborative research, especially scientist… https://t.co/Bfxn6qyS1e
# #124 date/time: 2018-10-18/11:26:41 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': -0.426715, 'label': 'negative'} emotion: {'sadness': 0.25503, 'joy': 0.070813, 'anger': 0.129998, 'disgust': 0.248143, 'fear': 0.315687}
# text:  Err how many? 4000 and most of them after Brexit ! So explain to me how did Russian bots influence Brexit ...asking… https://t.co/6oCWzOE5zF
# #125 date/time: 2018-10-18/11:26:58 country: GB coords: [-0.7576449999999999, 51.249951]
# sentiment: {'score': 0.674554, 'label': 'positive'} emotion: {'sadness': 0.059647, 'joy': 0.747847, 'anger': 0.002607, 'disgust': 0.050794, 'fear': 0.058728}
# text:  Nice little earner 😁😁😁😁
# #126 date/time: 2018-10-18/11:27:24 country: GB coords: [-3.3560220000000003, 56.037471]
# sentiment: {'score': 0.713531, 'label': 'positive'} emotion: {'sadness': 0.212888, 'joy': 0.247014, 'anger': 0.394785, 'disgust': 0.080384, 'fear': 0.176237}
# text:  @RossThomson_MP @DavidMundellDCT Ross  you need to ask @RuthDavidsonMSP to put a word in @theresa_may ear. If she d… https://t.co/8SckYpdIEM
# #127 date/time: 2018-10-18/11:27:40 country: GB coords: [-2.4568145, 53.092118]
# sentiment: {'score': 0.586593, 'label': 'positive'} emotion: {'sadness': 0.27857, 'joy': 0.175403, 'anger': 0.327047, 'disgust': 0.367213, 'fear': 0.096602}
# text:  #Brexit is not difficult.
# Offer a free trade deal and walk away.
# The #REMOANERS are deliberately making it difficul… https://t.co/tXP5n9qs7Y
# #128 date/time: 2018-10-18/11:27:54 country: NL coords: [4.508210999999999, 52.2737025]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.143526, 'joy': 0.124323, 'anger': 0.114194, 'disgust': 0.133286, 'fear': 0.06507}
# text:  @youngvulgarian @thhamilton Soggy-bottom Brexit?
# #129 date/time: 2018-10-18/11:27:59 country: GB coords: [0.5115780000000001, 52.2204505]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.419889, 'joy': 0.210788, 'anger': 0.206333, 'disgust': 0.182711, 'fear': 0.1407}
# text:  This is increasingly the feeling I am getting at #europeanParliament. Not there yet but anti-Brexit MEPs are gettin… https://t.co/olNxzOD8dj
# #130 date/time: 2018-10-18/11:29:02 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.411797, 'joy': 0.32683, 'anger': 0.011936, 'disgust': 0.308102, 'fear': 0.028796}
# text:  BREXIT - @marie_celie "when you look at Europe, the only city that matches London in terms of quality of life, cult… https://t.co/lJD598XXhg
# #131 date/time: 2018-10-18/11:29:18 country: IE coords: [-6.2476215, 53.354902499999994]
# sentiment: {'score': -0.346886, 'label': 'negative'} emotion: {'sadness': 0.066985, 'joy': 0.767086, 'anger': 0.031268, 'disgust': 0.032354, 'fear': 0.0527}
# text:  ‘I once laughed at their cluelessness. But I don’t find it funny any more, how they don’t think of us - or often, h… https://t.co/kQh1BDLe5f
# #132 date/time: 2018-10-18/11:29:20 country: IE coords: [-6.395643000000001, 53.906042]
# sentiment: {'score': -0.60682, 'label': 'negative'} emotion: {'sadness': 0.226672, 'joy': 0.163794, 'anger': 0.108762, 'disgust': 0.129455, 'fear': 0.222828}
# text:  I'm taking "this" out retirement for one final job. THIS
# #133 date/time: 2018-10-18/11:29:57 country: GB coords: [-1.76682, 53.8159335]
# sentiment: {'score': -0.755634, 'label': 'negative'} emotion: {'sadness': 0.56681, 'joy': 0.054284, 'anger': 0.346106, 'disgust': 0.175565, 'fear': 0.174603}
# text:  “The problem is not that I lied and promised everyone a mythical Cake and Eat It Brexit. The problem is Mrs May’s S… https://t.co/YiaNa8bQ3j
# #134 date/time: 2018-10-18/11:30:00 country: CL coords: [-70.515078, -33.485944]
# sentiment: {} emotion: {}
# text:  Esperamos que los jovenes entiendan. Y sientan la necesidad del voto. https://t.co/cx06FZlkPh
# #135 date/time: 2018-10-18/11:30:27 country: GB coords: [-2.915427, 53.4198785]
# sentiment: {'score': -0.707611, 'label': 'negative'} emotion: {'sadness': 0.314762, 'joy': 0.098705, 'anger': 0.137422, 'disgust': 0.096236, 'fear': 0.106199}
# text:  Shouldn’t take too long then.
# https://t.co/1LRtmPd7bC
# #136 date/time: 2018-10-18/11:30:35 country: GB coords: [-4.1407615, 51.686871499999995]
# sentiment: {'score': -0.439711, 'label': 'negative'} emotion: {'sadness': 0.109245, 'joy': 0.262102, 'anger': 0.170761, 'disgust': 0.04572, 'fear': 0.248452}
# text:  @naebD @rosslpete @DRossborough Why is he asking? Has new research been published? Has a BB spontaneously combusted… https://t.co/lBLm88HpTL
# #137 date/time: 2018-10-18/11:30:41 country: GB coords: [-3.5521435, 54.630171499999996]
# sentiment: {'score': -0.487816, 'label': 'negative'} emotion: {'sadness': 0.609072, 'joy': 0.171503, 'anger': 0.078423, 'disgust': 0.124443, 'fear': 0.140335}
# text:  I know Brexit is boring but...I can’t articulate anyone’s policy. As Peter Green sang “Oh Well”..
# #138 date/time: 2018-10-18/11:31:17 country: GB coords: [-0.148936, 51.500092]
# ...
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @ScaryChildren @liz6153 @IanMurrayMP @scotgov https://t.co/i6EU8qqB4O
# #608 date/time: 2018-10-18/14:01:40 country: GB coords: [-0.2631405, 51.5651955]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.154201, 'joy': 0.161531, 'anger': 0.070382, 'disgust': 0.123534, 'fear': 0.082055}
# text:  @njpart @mrjamesob @damocrat In your Brexit scenario - Norway means no border in Ireland = FOM or Switzerland which… https://t.co/OF3xvOzgxf
# #609 date/time: 2018-10-18/14:01:42 country: GB coords: [-6.81351, 54.667202]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.181624, 'joy': 0.509817, 'anger': 0.210927, 'disgust': 0.030182, 'fear': 0.183927}
# text:  Strand 3 of the Good Friday Agreement allows for bilateral deals between the UK and Ireland &gt;&gt;Britain wants exempti… https://t.co/5jIY5JM7q1
# #610 date/time: 2018-10-18/14:02:00 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @robertshrimsley
# #611 date/time: 2018-10-18/14:02:26 country: GB coords: [-1.7874955, 52.447226]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.0, 'joy': 0.0, 'anger': 0.0, 'disgust': 0.0, 'fear': 0.0}
# text:  @Janice4Brexit https://t.co/kWIBLN3Kaz
# #612 date/time: 2018-10-18/14:02:48 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': 0.719221, 'label': 'positive'} emotion: {'sadness': 0.104431, 'joy': 0.17507, 'anger': 0.109891, 'disgust': 0.117014, 'fear': 0.066156}
# text:  The conscience of Brexit speaks @Nigel_Farage
# #613 date/time: 2018-10-18/14:03:32 country: GB coords: [-2.366933, 51.3796495]
# sentiment: {} emotion: {}
# text:  WTAF?!
# #614 date/time: 2018-10-18/14:05:23 country: GB coords: [-2.23348, 53.4569525]
# sentiment: {'score': 0.900495, 'label': 'positive'} emotion: {'sadness': 0.03739, 'joy': 0.769129, 'anger': 0.020174, 'disgust': 0.023421, 'fear': 0.029653}
# text:  Fantastic day at the UK Seafood Summit hearing about the challenges and opportunities that will present the seafood… https://t.co/517bl9AkVs
# #615 date/time: 2018-10-18/14:05:34 country: GB coords: [-3.5243905, 55.898835500000004]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.115345, 'joy': 0.117113, 'anger': 0.316065, 'disgust': 0.572948, 'fear': 0.134304}
# text:  ‘Blow the doors off’ Mike should be saying:
#
# “The Independent newspaper is a blatant anti-Brexit rag, Not a lot of… https://t.co/A9XWUwGwcN
# #616 date/time: 2018-10-18/14:05:42 country: GB coords: [-3.1798, 51.497001499999996]
# sentiment: {'score': -0.560851, 'label': 'negative'} emotion: {'sadness': 0.181048, 'joy': 0.294641, 'anger': 0.05657, 'disgust': 0.390567, 'fear': 0.108989}
# text:  https://t.co/ltcyf5HQzA
# We’re staring head first into the abyss for the sake of flag waving jingoism, and our inabi… https://t.co/3qhmTiKnRC
# #617 date/time: 2018-10-18/14:05:57 country: BE coords: [4.375468, 50.855017000000004]
# sentiment: {} emotion: {}
# text:  El sindicato agrario inglés NFU quie hablar con el Gobierno Británico porque hay demasiada inucertidumbre en el sec… https://t.co/oy74PIlA8Q
# #618 date/time: 2018-10-18/14:06:01 country: GB coords: [0.5277305, 51.26357900000001]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.167856, 'joy': 0.08582, 'anger': 0.057188, 'disgust': 0.083524, 'fear': 0.109983}
# text:  @BritishNeuro statement related to Brexit and neuroscience research in the UK. https://t.co/3BU4uggdfL
# #619 date/time: 2018-10-18/14:06:18 country: GB coords: [0.044914, 51.5160475]
# sentiment: {'score': -0.76895, 'label': 'negative'} emotion: {'sadness': 0.337352, 'joy': 0.224673, 'anger': 0.133969, 'disgust': 0.41811, 'fear': 0.027378}
# text:  @southbankcentre If that Brexit supporter is there and how damaging it will be to the UK arts I am shocked you gave… https://t.co/kkWuR7DIuO
# #620 date/time: 2018-10-18/14:06:35 country: BE coords: [4.375468, 50.855017000000004]
# sentiment: {'score': -0.626294, 'label': 'negative'} emotion: {'sadness': 0.115905, 'joy': 0.147653, 'anger': 0.598353, 'disgust': 0.356138, 'fear': 0.04078}
# text:  I’m absolutely pissing myself laughing at these #PeoplesVote people.
#
# I’ve said for months, the final deal you all… https://t.co/1Um1NuEnQN
# #621 date/time: 2018-10-18/14:07:28 country: GB coords: [-4.2417514999999995, 55.85830249999999]
# sentiment: {'score': -0.715956, 'label': 'negative'} emotion: {'sadness': 0.094316, 'joy': 0.024947, 'anger': 0.570794, 'disgust': 0.392014, 'fear': 0.144044}
# text:  Pair of pricks
# #622 date/time: 2018-10-18/14:08:23 country: GB coords: [-2.0362915, 53.357307]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.131512, 'joy': 0.143646, 'anger': 0.100054, 'disgust': 0.105771, 'fear': 0.151974}
# text:  #Brexit has made the EU more popular than ever.
# #623 date/time: 2018-10-18/14:08:23 country: GB coords: [0.07886299999999999, 51.584990000000005]
# sentiment: {'score': -0.617649, 'label': 'negative'} emotion: {'sadness': 0.292266, 'joy': 0.069689, 'anger': 0.117674, 'disgust': 0.031832, 'fear': 0.659139}
# text:  US stock markets could enter bear markets due to huge debts and budget deficits due to growth worries as a result o… https://t.co/zcfB2zV9mY
# #624 date/time: 2018-10-18/14:08:55 country: ES coords: [2.954322, 42.232012499999996]
# sentiment: {} emotion: {}
# text:  @AdriaAlsina EU no vol saber res del Brexit fins que tingui el suport de +50% de la població UK. Dons fan referendu… https://t.co/8WjwfVULxg
# #625 date/time: 2018-10-18/14:08:56 country: SE coords: [17.980058999999997, 59.333670999999995]
# sentiment: {'score': -0.486214, 'label': 'negative'} emotion: {'sadness': 0.197172, 'joy': 0.078291, 'anger': 0.321037, 'disgust': 0.329333, 'fear': 0.384563}
# text:  ‘4000 Brexit tweets out of 10 Million’
#
# That and idiots like @louisemensch calling all and sundry ‘Russian spies’… https://t.co/bUVWlunmZm
# #626 date/time: 2018-10-18/14:09:06 country:  coords: [4.38273, 50.842126]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.168005, 'joy': 0.16122, 'anger': 0.147287, 'disgust': 0.306166, 'fear': 0.085579}
# text:  Angela Merkel tells journalists after #EUCO: “Each and everyone ought to prepare for a no-deal #Brexit scenario. Bu… https://t.co/Fe1OBr2Kcn
# #627 date/time: 2018-10-18/14:09:17 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': 0.867482, 'label': 'positive'} emotion: {'sadness': 0.438947, 'joy': 0.103561, 'anger': 0.296997, 'disgust': 0.258801, 'fear': 0.131887}
# text:  Putting aside #michaelmoore political persuasions, this man talks a lot of sense. If Michael had said this, as eloq… https://t.co/TtFcMcsrgi
# #628 date/time: 2018-10-18/14:09:23 country: GB coords: [-4.200441, 57.739454]
# sentiment: {'score': -0.426485, 'label': 'negative'} emotion: {'sadness': 0.414714, 'joy': 0.245441, 'anger': 0.071346, 'disgust': 0.092248, 'fear': 0.229416}
# text:  @BrunoAm05317727 Labour will get in and be so busy privatising everything they will forget about Brexit and when Br… https://t.co/N5xXeuIGDu
# #629 date/time: 2018-10-18/14:09:31 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': -0.836268, 'label': 'negative'} emotion: {'sadness': 0.429822, 'joy': 0.022119, 'anger': 0.018704, 'disgust': 0.372941, 'fear': 0.406269}
# text:  I doubt Old Little Bo Pete @peterjukes and Codswallop @carolecadwalla are likely to believe this 😳🇷🇺 and will call… https://t.co/1eTWro5Elt
# #630 date/time: 2018-10-18/14:09:32 country: GB coords: [-0.148936, 51.500092]
# sentiment: {'score': 0.867482, 'label': 'positive'} emotion: {'sadness': 0.438947, 'joy': 0.103561, 'anger': 0.296997, 'disgust': 0.258801, 'fear': 0.131887}
# text:  @Channel4News Putting aside #michaelmoore political persuasions, this man talks a lot of sense. If Michael had said… https://t.co/hI4p7J7faO
# #631 date/time: 2018-10-18/14:10:09 country: GB coords: [-0.1815875, 51.3618975]
# sentiment: {'score': 0.0, 'label': 'neutral'} emotion: {'sadness': 0.200396, 'joy': 0.08645, 'anger': 0.16115, 'disgust': 0.46711, 'fear': 0.125435}
# text:  I would like to know how much time has been wasted on #Brexit talks on Food&amp;Drink&amp;Hotel accommodations?… https://t.co/D76EgbJVbt
# #632 date/time: 2018-10-18/14:10:26 country: GB coords: [-0.442361, 51.537061]
# sentiment: {'score': -0.402138, 'label': 'negative'} emotion: {'sadness': 0.691993, 'joy': 0.016307, 'anger': 0.080544, 'disgust': 0.183412, 'fear': 0.223094}
# text:  https://t.co/L5mnKTgfVh Brexit Transition Period to be extended until all Leave Voters have died. @newsthump
# #633 date/time: 2018-10-18/14:10:39 country: GB coords: [-0.0706035, 51.464686]
# sentiment: {'score': -0.497587, 'label': 'negative'} emotion: {'sadness': 0.476547, 'joy': 0.095042, 'anger': 0.208061, 'disgust': 0.094967, 'fear': 0.241457}
# text:  So the company I work for is being asked for details about Brexit risk from their public sector customers. Seems li… https://t.co/LVdm5p79IX
# #634 date/time: 2018-10-18/14:11:09 country: GB coords: [-0.3922755, 51.6680785]
# sentiment: {'score': -0.803734, 'label': 'negative'} emotion: {'sadness': 0.444799, 'joy': 0.020773, 'anger': 0.600197, 'disgust': 0.120042, 'fear': 0.111689}
# text:  @bobmca1 @h8kes Don’t ever forget that @theresa_may will say and do anything to frustrate Brexit
# #635 date/time: 2018-10-18/14:11:39 country: GB coords: [-0.18919, 51.5037865]
# sentiment: {} emotion: {}
# text:  We leave!
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/http/client.py in _readinto_chunked(self, b)
#     577                 if len(mvb) <= chunk_left:
# --> 578                     n = self._safe_readinto(mvb)
#     579                     self.chunk_left = chunk_left - n
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/http/client.py in _safe_readinto(self, b)
#     624             if not n:
# --> 625                 raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
#     626             mvb = mvb[n:]
#
# IncompleteRead: IncompleteRead(0 bytes read, 512 more expected)
#
# During handling of the above exception, another exception occurred:
#
# IncompleteRead                            Traceback (most recent call last)
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/site-packages/urllib3/response.py in _error_catcher(self)
#     301             try:
# --> 302                 yield
#     303
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/http/client.py in read(self, amt)
#     447             b = bytearray(amt)
# --> 448             n = self.readinto(b)
#     449             return memoryview(b)[:n].tobytes()
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/http/client.py in readinto(self, b)
#     477         if self.chunked:
# --> 478             return self._readinto_chunked(b)
#     479
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/http/client.py in _readinto_chunked(self, b)
#     588         except IncompleteRead:
# --> 589             raise IncompleteRead(bytes(b[0:total_bytes]))
#     590
#
# IncompleteRead: IncompleteRead(0 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# <ipython-input-63-629c4fa478bf> in <module>()
#       8     ts = TwitterStreamer(hash_tag_list)
#       9     try:
# ---> 10         ts.stream_tweets(tweets_database)
#      11     except KeyboardInterrupt:
#      12         print("exited early")
#
# <ipython-input-62-b133699800db> in stream_tweets(self, tweets_database)
#      66         stream = Stream(twapi.auth, listener)
#      67         #This line filter Twitter Streams to capture data by the keywords:
# ---> 68         stream.filter(track=self.filter_list)
#
# ~/.local/lib/python3.5/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     448         self.session.params = {'delimited': 'length'}
#     449         self.host = 'stream.twitter.com'
# --> 450         self._start(async)
#     451
#     452     def sitestream(self, follow, stall_warnings=False,
#
# ~/.local/lib/python3.5/site-packages/tweepy/streaming.py in _start(self, async)
#     362             self._thread.start()
#     363         else:
# --> 364             self._run()
#     365
#     366     def on_closed(self, resp):
#
# ~/.local/lib/python3.5/site-packages/tweepy/streaming.py in _run(self)
#     295             # call a handler first so that the exception can be logged.
#     296             self.listener.on_exception(exc_info[1])
# --> 297             six.reraise(*exc_info)
#     298
#     299     def _data(self, data):
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# ~/.local/lib/python3.5/site-packages/tweepy/streaming.py in _run(self)
#     264                     self.snooze_time = self.snooze_time_step
#     265                     self.listener.on_connect()
# --> 266                     self._read_loop(resp)
#     267             except (Timeout, ssl.SSLError) as exc:
#     268                 # This is still necessary, as a SSLError can actually be
#
# ~/.local/lib/python3.5/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     314             length = 0
#     315             while not resp.raw.closed:
# --> 316                 line = buf.read_line().strip()
#     317                 if not line:
#     318                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# ~/.local/lib/python3.5/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     399                         # raised during streaming, so all calls with incorrect
#     400                         # Content-Length are caught.
# --> 401                         raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#     402
#     403         if data:
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/contextlib.py in __exit__(self, type, value, traceback)
#      75                 value = type()
#      76             try:
# ---> 77                 self.gen.throw(type, value, traceback)
#      78             except StopIteration as exc:
#      79                 # Suppress StopIteration *unless* it's the same exception that
#
# /usr/local/src/conda3_runtime/home/envs/DSX-Python35-Spark/lib/python3.5/site-packages/urllib3/response.py in _error_catcher(self)
#     318             except (HTTPException, SocketError) as e:
#     319                 # This includes IncompleteRead.
# --> 320                 raise ProtocolError('Connection broken: %r' % e, e)
#     321
#     322             # If no exception is thrown, we should avoid cleaning up
#
# ProtocolError: ('Connection broken: IncompleteRead(0 bytes read)', IncompleteRead(0 bytes read))
